# %% [markdown]
# ## Building an Artificial Neural Network model, to predict credit card defaulters for a month

# %%
# Library imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the dataset and verification

# %%
credit_data = pd.read_csv("D:\ML-Datasets\Jigsaw\credit_default_data.csv")
credit_data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
# Check for any missing values
credit_data.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %%
# Check the data structure
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29601 entries, 0 to 29600
# Data columns (total 25 columns):
# ID                            29601 non-null int64
# LIMIT_BAL                     29601 non-null int64
# SEX                           29601 non-null int64
# EDUCATION                     29601 non-null int64
# MARRIAGE                      29601 non-null int64
# AGE                           29601 non-null int64
# PAY_0                         29601 non-null int64
# PAY_2                         29601 non-null int64
# PAY_3                         29601 non-null int64
# PAY_4                         29601 non-null int64
# PAY_5                         29601 non-null int64
# PAY_6                         29601 non-null int64
# BILL_AMT1                     29601 non-null int64
# BILL_AMT2                     29601 non-null int64
# BILL_AMT3                     29601 non-null int64
# BILL_AMT4                     29601 non-null int64
# BILL_AMT5                     29601 non-null int64
# BILL_AMT6                     29601 non-null int64
# PAY_AMT1                      29601 non-null int64
# PAY_AMT2                      29601 non-null int64
# PAY_AMT3                      29601 non-null int64
# PAY_AMT4                      29601 non-null int64
# PAY_AMT5                      29601 non-null int64
# PAY_AMT6                      29601 non-null int64
# default payment next month    29601 non-null int64
# dtypes: int64(25)
# memory usage: 5.6 MB

# %%
# Check the summary statistics for applicable columns
credit_data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  29601.000000    29601.000000  29601.000000  29601.000000  29601.000000
# mean   14971.758927   167550.544914      1.603189      1.815479      1.555454
# std     8660.184430   129944.020953      0.489244      0.710399      0.518092
# min        1.000000    10000.000000      1.000000      1.000000      1.000000
# 25%     7474.000000    50000.000000      1.000000      1.000000      1.000000
# 50%    14953.000000   140000.000000      2.000000      2.000000      2.000000
# 75%    22463.000000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      4.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  29601.000000  29601.000000  29601.000000  29601.000000  29601.000000
# mean      35.464072     -0.014932     -0.131313     -0.163440     -0.218303
# std        9.213243      1.124503      1.199642      1.199793      1.172220
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   29601.000000   29601.000000   29601.000000   29601.000000
# mean   ...   43122.554204   40235.545184   38858.449816    5649.560319
# std    ...   64196.383913   60699.344884   59519.893043   16568.264941
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2329.000000    1780.000000    1278.000000    1000.000000
# 50%    ...   19005.000000   18091.000000   17118.000000    2100.000000
# 75%    ...   54271.000000   50072.000000   49121.000000    5005.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  2.960100e+04   29601.000000   29601.000000   29601.000000
# mean   5.894788e+03    5198.415898    4828.659268    4795.032735
# std    2.308919e+04   17580.914806   15711.057992   15244.217154
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    8.250000e+02     390.000000     298.000000     259.000000
# 50%    2.007000e+03    1800.000000    1500.000000    1500.000000
# 75%    5.000000e+03    4500.000000    4014.000000    4042.000000
# max    1.684259e+06  896040.000000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   29601.000000                29601.000000
# mean     5181.326374                    0.223134
# std     17657.260739                    0.416355
# min         0.000000                    0.000000
# 25%       138.000000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ### Data Explorations and Visualizations

# %%
# Explore the target variable
sns.countplot(credit_data['default payment next month'])
plt.title("Defaulters vs Non Defaulters")

credit_data['default payment next month'].value_counts()
# Out:
# 0    22996
# 1     6605
# Name: default payment next month, dtype: int64

# %%
# Explore variable LIMIT_BAL

sns.distplot(credit_data['LIMIT_BAL'], hist_kws=dict(edgecolor='k', linewidth=1), bins=10)

# %% [markdown]
# Highly negatively sekewed distribution. Most of the customers are at the lower end of the limit balance.

# %%
g = sns.FacetGrid(data=credit_data, hue='default payment next month')
g.map(sns.distplot, 'LIMIT_BAL').add_legend()
plt.title('Distribution of LIMIT_BAL by defaulter status')
# Out:
# Text(0.5, 1, 'Distribution of LIMIT_BAL by defaulter status')

# %% [markdown]
# There is an indication that defaulting customers have lower LIMIT_BAL

# %%
# Distribution of LIMIT_BAL by defaulter status (Another representation)

fig, axes = plt.subplots(nrows=1, ncols=2)
sns.distplot(credit_data[credit_data['default payment next month'] == 0]['LIMIT_BAL'], ax=axes[0])
axes[0].set_title('Default = 0')
sns.distplot(credit_data[credit_data['default payment next month'] == 1]['LIMIT_BAL'], ax=axes[1])
axes[1].set_title('Default = 1')
plt.tight_layout()

# %%
credit_data.groupby('default payment next month').describe()['LIMIT_BAL']
# Out:
#                               count           mean            std      min  \
# default payment next month
# 0                           22996.0  178299.965211  131876.835217  10000.0
# 1                            6605.0  130125.311128  115424.107801  10000.0
#
#                                 25%       50%       75%        max
# default payment next month
# 0                           70000.0  150000.0  250000.0  1000000.0
# 1                           50000.0   90000.0  200000.0   740000.0

# %%
sns.barplot(x='default payment next month',y='LIMIT_BAL',data=credit_data)
plt.title('Average LIMIT_BAL by defaulters')
# Out:
# Text(0.5, 1.0, 'Average LIMIT_BAL by defaulters')

# %%
sns.stripplot(x='default payment next month',y='LIMIT_BAL',data=credit_data,jitter=True)

# %%
sns.boxplot(x='default payment next month',y='LIMIT_BAL',data=credit_data)

# %%
# Explore the SEX variable

print('Distribution of Sex and Credit Default')
print(pd.crosstab(credit_data['SEX'], credit_data['default payment next month']))
print("\n")
print("Proportional distribution of Sex and Credit Default")
print(pd.crosstab(credit_data['SEX'], credit_data['default payment next month']).apply(lambda r: r/r.sum(), axis=1))
print("\n")
sns.countplot(x='default payment next month', hue='SEX', data=credit_data)
plt.title('SEX distribution by Defaulters')
# Out:
# Distribution of Sex and Credit Default
# default payment next month      0     1
# SEX
# 1                            8885  2861
# 2                           14111  3744
#
#
# Proportional distribution of Sex and Credit Default
# default payment next month         0         1
# SEX
# 1                           0.756428  0.243572
# 2                           0.790311  0.209689
# Text(0.5, 1.0, 'SEX distribution by Defaulters')

# %%
# Explore the EDUCATION variable

print('Distribution of EDUCATION and Credit Default')
print(pd.crosstab(credit_data['EDUCATION'], credit_data['default payment next month']))
print("\n")
print("Proportional distribution of EDUCATION and Credit Default")
print(pd.crosstab(credit_data['EDUCATION'], credit_data['default payment next month']).apply(lambda r: r/r.sum(), axis=1))
print("\n")
sns.countplot(x='default payment next month', hue='EDUCATION', data=credit_data)
plt.title('EDUCATION status by Defaulters')
# Out:
# Distribution of EDUCATION and Credit Default
# default payment next month      0     1
# EDUCATION
# 1                            8545  2036
# 2                           10695  3329
# 3                            3640  1233
# 4                             116     7
#
#
# Proportional distribution of EDUCATION and Credit Default
# default payment next month         0         1
# EDUCATION
# 1                           0.807580  0.192420
# 2                           0.762621  0.237379
# 3                           0.746973  0.253027
# 4                           0.943089  0.056911
# Text(0.5, 1.0, 'EDUCATION status by Defaulters')

# %%
# Explore the MARRIAGE variable

print('Distribution of MARRIAGE and Credit Default')
print(pd.crosstab(credit_data['MARRIAGE'], credit_data['default payment next month']))
print("\n")
print("Proportional distribution of MARRIAGE and Credit Default")
print(pd.crosstab(credit_data['MARRIAGE'], credit_data['default payment next month']).apply(lambda r: r/r.sum(), axis=1))
print("\n")
sns.countplot(x='default payment next month', hue='MARRIAGE', data=credit_data)
plt.title('MARRIAGE status by Defaulters')
# Out:
# Distribution of MARRIAGE and Credit Default
# default payment next month      0     1
# MARRIAGE
# 1                           10285  3192
# 2                           12477  3329
# 3                             234    84
#
#
# Proportional distribution of MARRIAGE and Credit Default
# default payment next month         0         1
# MARRIAGE
# 1                           0.763152  0.236848
# 2                           0.789384  0.210616
# 3                           0.735849  0.264151
# Text(0.5, 1.0, 'MARRIAGE status by Defaulters')

# %%
# Explore AGE variable

credit_data.groupby('default payment next month').describe()['AGE']
# Out:
#                               count       mean       std   min   25%   50%  \
# default payment next month
# 0                           22996.0  35.392851  9.069673  21.0  28.0  34.0
# 1                            6605.0  35.712036  9.693160  21.0  28.0  34.0
#
#                              75%   max
# default payment next month
# 0                           41.0  79.0
# 1                           42.0  75.0

# %%
sns.barplot(x='default payment next month',y='AGE',data=credit_data)

# %%
# Distribution of Age by Defaulters and Non Defaulters
fig,axes = plt.subplots(nrows=1, ncols=2)
sns.distplot(credit_data[credit_data['default payment next month'] == 0]['AGE'],ax=axes[0])
axes[0].set_title('Default = 0')
sns.distplot(credit_data[credit_data['default payment next month'] == 1]['AGE'],ax=axes[1])
axes[1].set_title('Default = 1')
plt.tight_layout()

# %%
g = sns.FacetGrid(data=credit_data, hue='default payment next month')
g.map(sns.distplot, 'AGE').add_legend()
plt.title('Distribution of AGE by defaulter status')
# Out:
# Text(0.5, 1, 'Distribution of AGE by defaulter status')

# %%
# Explore last six monthx bill amounts by defaulter status

fig,axes = plt.subplots(nrows=1, ncols=2)
sns.distplot(credit_data[credit_data['default payment next month'] == 0]['BILL_AMT1'],ax=axes[0])
axes[0].set_title('Default = 0')
sns.distplot(credit_data[credit_data['default payment next month'] == 1]['BILL_AMT1'],ax=axes[1])
axes[1].set_title('Default = 1')
plt.tight_layout()

# %%
# We will introduce two average variables for BILL_AMTs and PAY_AMTS and will consider only the average values

BILL_AMOUNTS = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
credit_data['AVG_BILL_AMT'] = credit_data[BILL_AMOUNTS].apply(lambda x:np.mean(x), axis=1)

PAY_AMOUNTS = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
credit_data['AVG_PAY_AMT'] = credit_data[PAY_AMOUNTS].apply(lambda x:np.mean(x), axis=1)

credit_data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...          0         0       689         0         0         0         0
# 1  ...       3261         0      1000      1000      1000         0      2000
# 2  ...      15549      1518      1500      1000      1000      1000      5000
# 3  ...      29547      2000      2019      1200      1100      1069      1000
# 4  ...      19131      2000     36681     10000      9000       689       679
#
#    default payment next month  AVG_BILL_AMT  AVG_PAY_AMT
# 0                           1   1284.000000   114.833333
# 1                           1   2846.166667   833.333333
# 2                           0  16942.166667  1836.333333
# 3                           0  38555.666667  1398.000000
# 4                           0  18223.166667  9841.500000
#
# [5 rows x 27 columns]

# %%
# Explore AVERAGE_BILL_AMT

credit_data.groupby('default payment next month').describe()['AVG_BILL_AMT']
# Out:
#                               count          mean           std           min  \
# default payment next month
# 0                           22996.0  45233.033093  62781.112724 -20913.333333
# 1                            6605.0  43381.514434  64315.605434 -56043.166667
#
#                                  25%           50%           75%  \
# default payment next month
# 0                           5009.625  21343.666667  58127.458333
# 1                           3753.500  19748.666667  51001.500000
#
#                                       max
# default payment next month
# 0                           877313.833333
# 1                           521248.333333

# %%
# Distribution of AVG_BILL_AMT by Defaulters and Non Defaulters

fig,axes = plt.subplots(nrows=1, ncols=2)
sns.distplot(credit_data[credit_data['default payment next month'] == 0]['AVG_BILL_AMT'],ax=axes[0])
axes[0].set_title('Default = 0')
sns.distplot(credit_data[credit_data['default payment next month'] == 1]['AVG_BILL_AMT'],ax=axes[1])
axes[1].set_title('Default = 1')
plt.tight_layout()

# %%
g = sns.FacetGrid(data=credit_data, hue='default payment next month')
g.map(sns.distplot, 'AVG_BILL_AMT').add_legend()
plt.title('Distribution of AVG_BILL_AMT by defaulter status')
# Out:
# Text(0.5, 1, 'Distribution of AVG_BILL_AMT by defaulter status')

# %%
# Explore AVG_PAY_AMT

credit_data.groupby('default payment next month').describe()['AVG_PAY_AMT']
# Out:
#                               count         mean           std  min  \
# default payment next month
# 0                           22996.0  5816.977612  10958.576724  0.0
# 1                            6605.0  3311.698738   6122.613311  0.0
#
#                                     25%          50%          75%  \
# default payment next month
# 0                           1241.791667  2752.083333  6177.916667
# 1                            805.666667  1607.666667  3533.333333
#
#                                       max
# default payment next month
# 0                           627344.333333
# 1                           117368.000000

# %%
# Distribution of AVG_PAY_AMT by Defaulters and Non Defaulters

fig,axes = plt.subplots(nrows=1, ncols=2)
sns.distplot(credit_data[credit_data['default payment next month'] == 0]['AVG_PAY_AMT'],ax=axes[0])
axes[0].set_title('Default = 0')
sns.distplot(credit_data[credit_data['default payment next month'] == 1]['AVG_PAY_AMT'],ax=axes[1])
axes[1].set_title('Default = 1')
plt.tight_layout()

# %%
g = sns.FacetGrid(data=credit_data, hue='default payment next month')
g.map(sns.distplot, 'AVG_PAY_AMT').add_legend()
plt.title('Distribution of AVG_PAY_AMT by defaulter status')
# Out:
# Text(0.5, 1, 'Distribution of AVG_PAY_AMT by defaulter status')

# %% [markdown]
# ### Data Preprocessing

# %%
credit_data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'AVG_BILL_AMT', 'AVG_PAY_AMT'],
#       dtype='object')

# %%
# create feature variable set and target variable
feature_cols = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'AVG_BILL_AMT', 'AVG_PAY_AMT']
features = credit_data[feature_cols].values
target = credit_data['default payment next month'].values

# %% [markdown]
# Since, We dont have any non-numerical variable, we dont need to perform any label encoding and since our variables are ordinal, as they have a relational order and we dont need one hot encoding

# %%
# Now we will split the dataset into training and test

from sklearn.model_selection import train_test_split

features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.3,
                                                                           random_state=101)

# %%
# perform feature scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
features_train = sc.fit_transform(features_train)
features_test = sc.transform(features_test)
print('Scaled features in training set')
print(features_train)
# Out:
# Scaled features in training set
# [[ 0.24519774 -1.24178073 -1.15187749 ... -0.62905323 -0.39633561
#    1.50670536]
#  [ 1.7792106   0.80529515 -1.15187749 ... -0.62905323 -0.33986887
#    1.57467636]
#  [-0.9053119   0.80529515  0.25197532 ... -0.62905323 -0.23812327
#   -0.03905095]
#  ...
#  [-0.13830547 -1.24178073 -1.15187749 ...  0.23745275  0.21597988
#   -0.37435999]
#  [ 0.55200031 -1.24178073 -1.15187749 ...  1.97046472 -0.66304456
#   -0.26001117]
#  [-0.9053119   0.80529515  1.65582813 ...  1.97046472  0.06406729
#   -0.2662229 ]]

# %% [markdown]
# ### Build the ANN

# %%
# import the libraries

import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Initialize the ANN

classifier = Sequential()

# %%
features.shape
# Out:
# (29601, 13)

# %%
# Adding the input layer and the first hidden layer of the neural network

classifier.add(Dense(activation='relu', input_dim=13, units=7, kernel_initializer='uniform'))

# %%
# Adding the second hidden layer

classifier.add(Dense(activation='relu', units=7, kernel_initializer='uniform'))

# %%
# Adding the output layer

classifier.add(Dense(activation='sigmoid', units=1, kernel_initializer='uniform'))

# %%
# Compiling the ANN

classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Making Predictions and Evaluating the model

# %%
# Fitting the ANN into the training set

classifier.fit(x=features_train, y=target_train, batch_size=10, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 20720/20720 [==============================] - 5s 240us/step - loss: 0.4749 - accuracy: 0.8034
# Epoch 2/100
# 20720/20720 [==============================] - 5s 226us/step - loss: 0.4501 - accuracy: 0.8145
# Epoch 3/100
# 20720/20720 [==============================] - 5s 225us/step - loss: 0.4483 - accuracy: 0.8155
# Epoch 4/100
# 20720/20720 [==============================] - 5s 225us/step - loss: 0.4472 - accuracy: 0.8156
# Epoch 5/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4463 - accuracy: 0.8164
# Epoch 6/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4457 - accuracy: 0.8159
# Epoch 7/100
# 20720/20720 [==============================] - 5s 225us/step - loss: 0.4446 - accuracy: 0.8170
# Epoch 8/100
# 20720/20720 [==============================] - 5s 225us/step - loss: 0.4439 - accuracy: 0.8167
# Epoch 9/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4424 - accuracy: 0.8172
# Epoch 10/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4415 - accuracy: 0.8165
# Epoch 11/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4409 - accuracy: 0.8179
# Epoch 12/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4404 - accuracy: 0.8180
# Epoch 13/100
# 20720/20720 [==============================] - 5s 224us/step - loss: 0.4394 - accuracy: 0.8177
# Epoch 14/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4390 - accuracy: 0.8176
# Epoch 15/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4384 - accuracy: 0.8184
# Epoch 16/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4380 - accuracy: 0.8174
# Epoch 17/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4376 - accuracy: 0.8175
# Epoch 18/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4377 - accuracy: 0.8171
# Epoch 19/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4375 - accuracy: 0.8178
# Epoch 20/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4375 - accuracy: 0.8181
# Epoch 21/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4371 - accuracy: 0.8186
# Epoch 22/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4367 - accuracy: 0.8182
# Epoch 23/100
# 20720/20720 [==============================] - 5s 233us/step - loss: 0.4370 - accuracy: 0.8178
# Epoch 24/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4364 - accuracy: 0.8187
# Epoch 25/100
# 20720/20720 [==============================] - 5s 233us/step - loss: 0.4362 - accuracy: 0.8184
# Epoch 26/100
# 20720/20720 [==============================] - 5s 234us/step - loss: 0.4364 - accuracy: 0.8174
# Epoch 27/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4362 - accuracy: 0.8179
# Epoch 28/100
# 20720/20720 [==============================] - 5s 232us/step - loss: 0.4358 - accuracy: 0.8188
# Epoch 29/100
# 20720/20720 [==============================] - 5s 231us/step - loss: 0.4360 - accuracy: 0.8190
# Epoch 30/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4359 - accuracy: 0.8189
# Epoch 31/100
# 20720/20720 [==============================] - 5s 231us/step - loss: 0.4356 - accuracy: 0.8188
# Epoch 32/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4357 - accuracy: 0.8184
# Epoch 33/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4356 - accuracy: 0.8194
# Epoch 34/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4356 - accuracy: 0.8197
# Epoch 35/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4354 - accuracy: 0.8189
# Epoch 36/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4352 - accuracy: 0.8176
# Epoch 37/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4351 - accuracy: 0.8184
# Epoch 38/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4345 - accuracy: 0.8185
# Epoch 39/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4343 - accuracy: 0.8183
# Epoch 40/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4348 - accuracy: 0.8190
# Epoch 41/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4344 - accuracy: 0.8187
# Epoch 42/100
# 20720/20720 [==============================] - 5s 225us/step - loss: 0.4348 - accuracy: 0.8187
# Epoch 43/100
# 20720/20720 [==============================] - 5s 231us/step - loss: 0.4346 - accuracy: 0.8193
# Epoch 44/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4344 - accuracy: 0.8196
# Epoch 45/100
# 20720/20720 [==============================] - 5s 228us/step - loss: 0.4346 - accuracy: 0.8194
# Epoch 46/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4342 - accuracy: 0.8198
# Epoch 47/100
# 20720/20720 [==============================] - 5s 231us/step - loss: 0.4343 - accuracy: 0.8190
# Epoch 48/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4342 - accuracy: 0.8197
# Epoch 49/100
# 20720/20720 [==============================] - 5s 228us/step - loss: 0.4339 - accuracy: 0.8194
# Epoch 50/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4338 - accuracy: 0.8201
# Epoch 51/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4338 - accuracy: 0.8195
# Epoch 52/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4338 - accuracy: 0.8185
# Epoch 53/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4339 - accuracy: 0.8192
# Epoch 54/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4337 - accuracy: 0.8195
# Epoch 55/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4337 - accuracy: 0.8191
# Epoch 56/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4329 - accuracy: 0.8194
# Epoch 57/100
# 20720/20720 [==============================] - 5s 229us/step - loss: 0.4337 - accuracy: 0.8194
# Epoch 58/100
# 20720/20720 [==============================] - 5s 231us/step - loss: 0.4334 - accuracy: 0.8199
# Epoch 59/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4336 - accuracy: 0.8193
# Epoch 60/100
# 20720/20720 [==============================] - 5s 226us/step - loss: 0.4335 - accuracy: 0.8181
# Epoch 61/100
# 20720/20720 [==============================] - 5s 225us/step - loss: 0.4334 - accuracy: 0.8188
# Epoch 62/100
# 20720/20720 [==============================] - 5s 226us/step - loss: 0.4333 - accuracy: 0.8191
# Epoch 63/100
# 20720/20720 [==============================] - 5s 226us/step - loss: 0.4334 - accuracy: 0.8187
# Epoch 64/100
# 20720/20720 [==============================] - 5s 230us/step - loss: 0.4335 - accuracy: 0.8191
# Epoch 65/100
# 20720/20720 [==============================] - 5s 231us/step - loss: 0.4330 - accuracy: 0.8193
# Epoch 66/100
# 20720/20720 [==============================] - 5s 224us/step - loss: 0.4330 - accuracy: 0.8189
# Epoch 67/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4334 - accuracy: 0.8183
# Epoch 68/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4335 - accuracy: 0.8186
# Epoch 69/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4330 - accuracy: 0.8181
# Epoch 70/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4327 - accuracy: 0.8199
# Epoch 71/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4331 - accuracy: 0.8188
# Epoch 72/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4330 - accuracy: 0.8194
# Epoch 73/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4327 - accuracy: 0.8187
# Epoch 74/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4328 - accuracy: 0.8197
# Epoch 75/100
# 20720/20720 [==============================] - 5s 219us/step - loss: 0.4322 - accuracy: 0.8201
# Epoch 76/100
# 20720/20720 [==============================] - 5s 219us/step - loss: 0.4328 - accuracy: 0.8195
# Epoch 77/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4324 - accuracy: 0.8191
# Epoch 78/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4327 - accuracy: 0.8192
# Epoch 79/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4323 - accuracy: 0.8194
# Epoch 80/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4322 - accuracy: 0.8197
# Epoch 81/100
# 20720/20720 [==============================] - 5s 223us/step - loss: 0.4325 - accuracy: 0.8188
# Epoch 82/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4322 - accuracy: 0.8191
# Epoch 83/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4323 - accuracy: 0.8188
# Epoch 84/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4322 - accuracy: 0.8190
# Epoch 85/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4323 - accuracy: 0.8195
# Epoch 86/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4322 - accuracy: 0.8194
# Epoch 87/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4321 - accuracy: 0.8196
# Epoch 88/100
# 20720/20720 [==============================] - 5s 219us/step - loss: 0.4318 - accuracy: 0.8189
# Epoch 89/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4321 - accuracy: 0.8205
# Epoch 90/100
# 20720/20720 [==============================] - 5s 219us/step - loss: 0.4316 - accuracy: 0.8198
# Epoch 91/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4316 - accuracy: 0.8195
# Epoch 92/100
# 20720/20720 [==============================] - 5s 228us/step - loss: 0.4317 - accuracy: 0.8194
# Epoch 93/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4314 - accuracy: 0.8202
# Epoch 94/100
# 20720/20720 [==============================] - 5s 226us/step - loss: 0.4317 - accuracy: 0.8194
# Epoch 95/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4317 - accuracy: 0.8194
# Epoch 96/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4321 - accuracy: 0.8192
# Epoch 97/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4313 - accuracy: 0.8193
# Epoch 98/100
# 20720/20720 [==============================] - 5s 221us/step - loss: 0.4316 - accuracy: 0.8187
# Epoch 99/100
# 20720/20720 [==============================] - 5s 220us/step - loss: 0.4313 - accuracy: 0.8188
# Epoch 100/100
# 20720/20720 [==============================] - 5s 222us/step - loss: 0.4317 - accuracy: 0.8196

# %%
# predicting the test results

target_predictions = classifier.predict(features_test)
target_predictions
# Out:
# array([[0.13418892],
#        [0.6363374 ],
#        [0.8356948 ],
#        ...,
#        [0.11914766],
#        [0.7562989 ],
#        [0.45882544]], dtype=float32)

# %%
# So the target_predictions has probabilities, in order to use it in confusion matrix

target_predictions = (target_predictions > 0.5)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

print('Confusion Matrix')
print(confusion_matrix(target_test, target_predictions))
print("\n")
print("Accuracy Score")
print(accuracy_score(target_test, target_predictions))
print("\n")
print("Classification Report")
print(classification_report(target_test, target_predictions))
# Out:
# Confusion Matrix
# [[6573  356]
#  [1218  734]]
#
#
# Accuracy Score
# 0.8227677063393762
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      6929
#            1       0.67      0.38      0.48      1952
#
#     accuracy                           0.82      8881
#    macro avg       0.76      0.66      0.69      8881
# weighted avg       0.81      0.82      0.80      8881

# %% [markdown]
# ### Evaluating, Improving and Tuning the ANN

# %% [markdown]
# #### Implementing the K-Fold cross validation - Evaluating the model

# %%
# Evaluating the model

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score

def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(activation='relu', input_dim=13, units=7, kernel_initializer='uniform'))
    classifier.add(Dense(activation='relu', units=7, kernel_initializer='uniform'))
    classifier.add(Dense(activation='sigmoid', units=1, kernel_initializer='uniform'))
    classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return classifier

classifier = KerasClassifier(build_fn=build_classifier, batch_size=10, epochs=100)
# Out:
# Using TensorFlow backend.

# %%
# Run the K-Fold cross validation

from datetime import datetime
start = datetime.now()
accuracies = cross_val_score(estimator=classifier, X=features_train, y=target_train, cv=10, n_jobs=-2, verbose=1)
end = datetime.now()
print("Time Taken :", (end-start))
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 15 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   3 out of  10 | elapsed:  3.2min remaining:  7.6min
# Time Taken : 0:03:17.014830
# [Parallel(n_jobs=-2)]: Done  10 out of  10 | elapsed:  3.3min finished

# %%
# relevant accuracy and variance for the model

print("Accuracy of the model")
print(accuracies.mean())
print("Variance of the model")
print(accuracies.std())
# Out:
# Accuracy of the model
# 0.8160714268684387
# Variance of the model
# 0.008022192578921186

# %% [markdown]
# Since the variance is very low, we dont need to implement Dropout regularization

# %% [markdown]
# ### Tuning the ANN - Parameter tuning

# %%
# Note this code is only valid if GPU is being used for training

# Before we run the parameter tuning, we will work with little gpu memory allocation
# we will only use that much of memory of gpu as it is needed - allow the growth of gpu memory as it is needed

import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(activation='relu', input_dim=13, units=7, kernel_initializer='uniform'))
    classifier.add(Dense(activation='relu', units=7, kernel_initializer='uniform'))
    classifier.add(Dense(activation='sigmoid', units=1, kernel_initializer='uniform'))
    classifier.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return classifier

classifier = KerasClassifier(build_fn=build_classifier)

# create a dictionary with hyper parameters
params = {'batch_size': [25, 50], 'epochs': [25, 50,], 'optimizer': ['adam', 'rmsprop']}
# create the grid search object - with the number of folds for k-fold cross validation
# scoring of each of the param in params dictionary will happen based on accuracy
grid_search = GridSearchCV(estimator=classifier, param_grid=params, scoring='accuracy', cv=10, verbose=1)
# we will now fit this grid_search object onto our training sets
grid_search = grid_search.fit(features_train, target_train)

# Now to get the best selection of parameters and best accuracy
print("Best Parameters")
best_params = grid_search.best_params_
print(best_params)
print("Best Accuracy")
best_accuracy=grid_search.best_score_
print(best_accuracy)
# Out:
# Using TensorFlow backend.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# Epoch 1/25
# 18648/18648 [==============================] - 2s 110us/step - loss: 0.5105 - accuracy: 0.7774
# Epoch 2/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4587 - accuracy: 0.7781
# Epoch 3/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4527 - accuracy: 0.8142
# Epoch 4/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4501 - accuracy: 0.8156
# Epoch 5/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4483 - accuracy: 0.8155
# Epoch 6/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4470 - accuracy: 0.8160
# Epoch 7/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4464 - accuracy: 0.8152
# Epoch 8/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4458 - accuracy: 0.8171
# Epoch 9/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4453 - accuracy: 0.8164
# Epoch 10/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4448 - accuracy: 0.8167
# Epoch 11/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4449 - accuracy: 0.8169
# Epoch 12/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4445 - accuracy: 0.8176
# Epoch 13/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4442 - accuracy: 0.8173
# Epoch 14/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4437 - accuracy: 0.8178
# Epoch 15/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4437 - accuracy: 0.8175
# Epoch 16/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4436 - accuracy: 0.8174
# Epoch 17/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4432 - accuracy: 0.8175
# Epoch 18/25
# 18648/18648 [==============================] - 2s 95us/step - loss: 0.4430 - accuracy: 0.8171
# Epoch 19/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4430 - accuracy: 0.8177
# Epoch 20/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4429 - accuracy: 0.8174
# Epoch 21/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4428 - accuracy: 0.8175
# Epoch 22/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4425 - accuracy: 0.8178
# Epoch 23/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4427 - accuracy: 0.8175
# Epoch 24/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4424 - accuracy: 0.8171
# Epoch 25/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4424 - accuracy: 0.8170
# Epoch 1/25
# 18648/18648 [==============================] - 2s 97us/step - loss: 0.5131 - accuracy: 0.7932
# Epoch 2/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4538 - accuracy: 0.8113
# Epoch 3/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4509 - accuracy: 0.8131
# Epoch 4/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4495 - accuracy: 0.8147
# Epoch 5/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4484 - accuracy: 0.8150
# Epoch 6/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4476 - accuracy: 0.8152
# Epoch 7/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4473 - accuracy: 0.8165
# Epoch 8/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4470 - accuracy: 0.8146
# Epoch 9/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4465 - accuracy: 0.8161
# Epoch 10/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4461 - accuracy: 0.8160
# Epoch 11/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4456 - accuracy: 0.8156
# Epoch 12/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4451 - accuracy: 0.8149
# Epoch 13/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4446 - accuracy: 0.8156
# Epoch 14/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4441 - accuracy: 0.8161
# Epoch 15/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4433 - accuracy: 0.8154
# Epoch 16/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4429 - accuracy: 0.8164
# Epoch 17/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4421 - accuracy: 0.8156
# Epoch 18/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4417 - accuracy: 0.8157
# Epoch 19/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4413 - accuracy: 0.8167
# Epoch 20/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4411 - accuracy: 0.8161
# Epoch 21/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4409 - accuracy: 0.8163
# Epoch 22/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4405 - accuracy: 0.8159
# Epoch 23/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4402 - accuracy: 0.8164
# Epoch 24/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4403 - accuracy: 0.8162
# Epoch 25/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4402 - accuracy: 0.8162
# Epoch 1/25
# 18648/18648 [==============================] - 2s 96us/step - loss: 0.5261 - accuracy: 0.7721
# Epoch 2/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4734 - accuracy: 0.7998
# Epoch 3/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4636 - accuracy: 0.8132
# Epoch 4/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4591 - accuracy: 0.8148
# Epoch 5/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4568 - accuracy: 0.8150
# Epoch 6/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4542 - accuracy: 0.8152
# Epoch 7/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4519 - accuracy: 0.8146
# Epoch 8/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4496 - accuracy: 0.8153
# Epoch 9/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4485 - accuracy: 0.8152
# Epoch 10/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4473 - accuracy: 0.8149
# Epoch 11/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4474 - accuracy: 0.8152
# Epoch 12/25
# 18648/18648 [==============================] - 2s 95us/step - loss: 0.4465 - accuracy: 0.8152
# Epoch 13/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4461 - accuracy: 0.8152
# Epoch 14/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4461 - accuracy: 0.8163
# Epoch 15/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4453 - accuracy: 0.8152
# Epoch 16/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4449 - accuracy: 0.8163
# Epoch 17/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4452 - accuracy: 0.8167
# Epoch 18/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4445 - accuracy: 0.8172
# Epoch 19/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4446 - accuracy: 0.8163
# Epoch 20/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4441 - accuracy: 0.8166
# Epoch 21/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4446 - accuracy: 0.8168
# Epoch 22/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4445 - accuracy: 0.8169
# Epoch 23/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4437 - accuracy: 0.8169
# Epoch 24/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4440 - accuracy: 0.8162
# Epoch 25/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4437 - accuracy: 0.8152
# Epoch 1/25
# 18648/18648 [==============================] - 2s 96us/step - loss: 0.5103 - accuracy: 0.7911
# Epoch 2/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.4525 - accuracy: 0.8124
# Epoch 3/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4498 - accuracy: 0.8158
# Epoch 4/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.4485 - accuracy: 0.8167
# Epoch 5/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4477 - accuracy: 0.8164
# Epoch 6/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4469 - accuracy: 0.8168
# Epoch 7/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4466 - accuracy: 0.8168
# Epoch 8/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4460 - accuracy: 0.8168
# Epoch 9/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.4457 - accuracy: 0.8172
# Epoch 10/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4454 - accuracy: 0.8169
# Epoch 11/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4452 - accuracy: 0.8164
# Epoch 12/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4450 - accuracy: 0.8172
# Epoch 13/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.4447 - accuracy: 0.8182
# Epoch 14/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4444 - accuracy: 0.8174
# Epoch 15/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4441 - accuracy: 0.8177
# Epoch 16/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.4435 - accuracy: 0.8182
# Epoch 17/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4433 - accuracy: 0.8179
# Epoch 18/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4425 - accuracy: 0.8178
# Epoch 19/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.4418 - accuracy: 0.8190
# Epoch 20/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4413 - accuracy: 0.8179
# Epoch 21/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4407 - accuracy: 0.8187
# Epoch 22/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4404 - accuracy: 0.8190
# Epoch 23/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4401 - accuracy: 0.8183
# Epoch 24/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4395 - accuracy: 0.8182
# Epoch 25/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4391 - accuracy: 0.8181
# Epoch 1/25
# 18648/18648 [==============================] - 2s 97us/step - loss: 0.5059 - accuracy: 0.7765
# Epoch 2/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4565 - accuracy: 0.7851
# Epoch 3/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4509 - accuracy: 0.8141
# Epoch 4/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4490 - accuracy: 0.8148
# Epoch 5/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4471 - accuracy: 0.8160
# Epoch 6/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4460 - accuracy: 0.8150
# Epoch 7/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4452 - accuracy: 0.8160
# Epoch 8/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4446 - accuracy: 0.8163
# Epoch 9/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4443 - accuracy: 0.8149
# Epoch 10/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4442 - accuracy: 0.8154
# Epoch 11/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4435 - accuracy: 0.8154
# Epoch 12/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4436 - accuracy: 0.8163
# Epoch 13/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4432 - accuracy: 0.8157
# Epoch 14/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4427 - accuracy: 0.8163
# Epoch 15/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4426 - accuracy: 0.8155
# Epoch 16/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4426 - accuracy: 0.8164
# Epoch 17/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4425 - accuracy: 0.8164
# Epoch 18/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4420 - accuracy: 0.8157
# Epoch 19/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4421 - accuracy: 0.8164
# Epoch 20/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4422 - accuracy: 0.8163
# Epoch 21/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4419 - accuracy: 0.8164
# Epoch 22/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4421 - accuracy: 0.8164
# Epoch 23/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4415 - accuracy: 0.8170
# Epoch 24/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4417 - accuracy: 0.8176
# Epoch 25/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4414 - accuracy: 0.8169
# Epoch 1/25
# 18648/18648 [==============================] - 2s 96us/step - loss: 0.5197 - accuracy: 0.7753
# Epoch 2/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4813 - accuracy: 0.7753
# Epoch 3/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4754 - accuracy: 0.7883
# Epoch 4/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4730 - accuracy: 0.8022
# Epoch 5/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4720 - accuracy: 0.8045
# Epoch 6/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4715 - accuracy: 0.8066
# Epoch 7/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4713 - accuracy: 0.8073
# Epoch 8/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4706 - accuracy: 0.8078
# Epoch 9/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4709 - accuracy: 0.8074
# Epoch 10/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4705 - accuracy: 0.8081
# Epoch 11/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4705 - accuracy: 0.8096
# Epoch 12/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4703 - accuracy: 0.8080
# Epoch 13/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4699 - accuracy: 0.8079
# Epoch 14/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4701 - accuracy: 0.8093
# Epoch 15/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4698 - accuracy: 0.8105
# Epoch 16/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4700 - accuracy: 0.8082
# Epoch 17/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4697 - accuracy: 0.8074
# Epoch 18/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4701 - accuracy: 0.8109
# Epoch 19/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4702 - accuracy: 0.8085
# Epoch 20/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4699 - accuracy: 0.8098
# Epoch 21/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4700 - accuracy: 0.8093
# Epoch 22/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4697 - accuracy: 0.8090
# Epoch 23/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4700 - accuracy: 0.8095
# Epoch 24/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4698 - accuracy: 0.8100
# Epoch 25/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4700 - accuracy: 0.8085
# Epoch 1/25
# 18648/18648 [==============================] - 2s 97us/step - loss: 0.5071 - accuracy: 0.7943
# Epoch 2/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4504 - accuracy: 0.8140
# Epoch 3/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4478 - accuracy: 0.8168
# Epoch 4/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4467 - accuracy: 0.8172
# Epoch 5/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.4459 - accuracy: 0.8165
# Epoch 6/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4453 - accuracy: 0.8182
# Epoch 7/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4445 - accuracy: 0.8178
# Epoch 8/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4437 - accuracy: 0.8185
# Epoch 9/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4426 - accuracy: 0.8184
# Epoch 10/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4420 - accuracy: 0.8185
# Epoch 11/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4412 - accuracy: 0.8191
# Epoch 12/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4407 - accuracy: 0.8192
# Epoch 13/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4399 - accuracy: 0.8196
# Epoch 14/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4392 - accuracy: 0.8183
# Epoch 15/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4393 - accuracy: 0.8198
# Epoch 16/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4387 - accuracy: 0.8188
# Epoch 17/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4386 - accuracy: 0.8187
# Epoch 18/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4383 - accuracy: 0.8191
# Epoch 19/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4380 - accuracy: 0.8191
# Epoch 20/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4379 - accuracy: 0.8183
# Epoch 21/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4375 - accuracy: 0.8188
# Epoch 22/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4376 - accuracy: 0.8197
# Epoch 23/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4373 - accuracy: 0.8193
# Epoch 24/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4374 - accuracy: 0.8182
# Epoch 25/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4371 - accuracy: 0.8190
# Epoch 1/25
# 18648/18648 [==============================] - 2s 97us/step - loss: 0.5126 - accuracy: 0.7963
# Epoch 2/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.4544 - accuracy: 0.8142
# Epoch 3/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4516 - accuracy: 0.8148
# Epoch 4/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4505 - accuracy: 0.8153
# Epoch 5/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4499 - accuracy: 0.8152
# Epoch 6/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4491 - accuracy: 0.8161
# Epoch 7/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4463 - accuracy: 0.8168
# Epoch 8/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4440 - accuracy: 0.8168
# Epoch 9/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4431 - accuracy: 0.8172
# Epoch 10/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4423 - accuracy: 0.8181
# Epoch 11/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4418 - accuracy: 0.8177
# Epoch 12/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4414 - accuracy: 0.8169
# Epoch 13/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4408 - accuracy: 0.8177
# Epoch 14/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4403 - accuracy: 0.8176
# Epoch 15/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4401 - accuracy: 0.8183
# Epoch 16/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4398 - accuracy: 0.8180
# Epoch 17/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4392 - accuracy: 0.8178
# Epoch 18/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4393 - accuracy: 0.8172
# Epoch 19/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4389 - accuracy: 0.8178
# Epoch 20/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4388 - accuracy: 0.8189
# Epoch 21/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4386 - accuracy: 0.8181
# Epoch 22/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4385 - accuracy: 0.8184
# Epoch 23/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4381 - accuracy: 0.8181
# Epoch 24/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4379 - accuracy: 0.8185
# Epoch 25/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4378 - accuracy: 0.8179
# Epoch 1/25
# 18648/18648 [==============================] - 2s 98us/step - loss: 0.5176 - accuracy: 0.7756
# Epoch 2/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4804 - accuracy: 0.7756
# Epoch 3/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4744 - accuracy: 0.7862
# Epoch 4/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4716 - accuracy: 0.8007
# Epoch 5/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4699 - accuracy: 0.8082
# Epoch 6/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4697 - accuracy: 0.8074
# Epoch 7/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4692 - accuracy: 0.8097
# Epoch 8/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4689 - accuracy: 0.8100
# Epoch 9/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4685 - accuracy: 0.8100
# Epoch 10/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4684 - accuracy: 0.8101
# Epoch 11/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4680 - accuracy: 0.8099
# Epoch 12/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4682 - accuracy: 0.8114
# Epoch 13/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4680 - accuracy: 0.8111
# Epoch 14/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4679 - accuracy: 0.8114
# Epoch 15/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4682 - accuracy: 0.8100
# Epoch 16/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4679 - accuracy: 0.8116
# Epoch 17/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4678 - accuracy: 0.8114
# Epoch 18/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4677 - accuracy: 0.8105
# Epoch 19/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4679 - accuracy: 0.8115
# Epoch 20/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4676 - accuracy: 0.8116
# Epoch 21/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4678 - accuracy: 0.8117
# Epoch 22/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4678 - accuracy: 0.8123
# Epoch 23/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4674 - accuracy: 0.8111
# Epoch 24/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4678 - accuracy: 0.8127
# Epoch 25/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4676 - accuracy: 0.8112
# Epoch 1/25
# 18648/18648 [==============================] - 2s 97us/step - loss: 0.5149 - accuracy: 0.7946
# Epoch 2/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4539 - accuracy: 0.8113
# Epoch 3/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4511 - accuracy: 0.8152
# Epoch 4/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4498 - accuracy: 0.8150
# Epoch 5/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4486 - accuracy: 0.8160
# Epoch 6/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4476 - accuracy: 0.8150
# Epoch 7/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4472 - accuracy: 0.8140
# Epoch 8/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4465 - accuracy: 0.8154
# Epoch 9/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4458 - accuracy: 0.8152
# Epoch 10/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4450 - accuracy: 0.8154
# Epoch 11/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4442 - accuracy: 0.8156
# Epoch 12/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4430 - accuracy: 0.8162
# Epoch 13/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4426 - accuracy: 0.8167
# Epoch 14/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4416 - accuracy: 0.8171
# Epoch 15/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4408 - accuracy: 0.8168
# Epoch 16/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4408 - accuracy: 0.8165
# Epoch 17/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4402 - accuracy: 0.8164
# Epoch 18/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4395 - accuracy: 0.8163
# Epoch 19/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4393 - accuracy: 0.8163
# Epoch 20/25
# 18648/18648 [==============================] - 2s 92us/step - loss: 0.4388 - accuracy: 0.8169
# Epoch 21/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4381 - accuracy: 0.8165
# Epoch 22/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4379 - accuracy: 0.8174
# Epoch 23/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4378 - accuracy: 0.8169
# Epoch 24/25
# 18648/18648 [==============================] - 2s 94us/step - loss: 0.4375 - accuracy: 0.8167
# Epoch 25/25
# 18648/18648 [==============================] - 2s 93us/step - loss: 0.4374 - accuracy: 0.8175
# Epoch 1/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.5256 - accuracy: 0.7771
# Epoch 2/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4648 - accuracy: 0.7777
# Epoch 3/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4567 - accuracy: 0.7953
# Epoch 4/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4527 - accuracy: 0.8156
# Epoch 5/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4504 - accuracy: 0.8159
# Epoch 6/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4488 - accuracy: 0.8167
# Epoch 7/25
# 18648/18648 [==============================] - 2s 84us/step - loss: 0.4476 - accuracy: 0.8173
# Epoch 8/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4471 - accuracy: 0.8170
# Epoch 9/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4463 - accuracy: 0.8167
# Epoch 10/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4459 - accuracy: 0.8168
# Epoch 11/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4456 - accuracy: 0.8173
# Epoch 12/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4453 - accuracy: 0.8172
# Epoch 13/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4452 - accuracy: 0.8175
# Epoch 14/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4447 - accuracy: 0.8175
# Epoch 15/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4446 - accuracy: 0.8175
# Epoch 16/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4445 - accuracy: 0.8179
# Epoch 17/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4444 - accuracy: 0.8175
# Epoch 18/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4441 - accuracy: 0.8167
# Epoch 19/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4441 - accuracy: 0.8172
# Epoch 20/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4437 - accuracy: 0.8174
# Epoch 21/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4437 - accuracy: 0.8176
# Epoch 22/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4436 - accuracy: 0.8178
# Epoch 23/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4432 - accuracy: 0.8180
# Epoch 24/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4436 - accuracy: 0.8174
# Epoch 25/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4434 - accuracy: 0.8180
# Epoch 1/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.5172 - accuracy: 0.7750
# Epoch 2/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4644 - accuracy: 0.7750
# Epoch 3/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4567 - accuracy: 0.8044
# Epoch 4/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4525 - accuracy: 0.8133
# Epoch 5/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4510 - accuracy: 0.8145
# Epoch 6/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4497 - accuracy: 0.8149
# Epoch 7/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4491 - accuracy: 0.8156
# Epoch 8/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4487 - accuracy: 0.8148
# Epoch 9/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4478 - accuracy: 0.8157
# Epoch 10/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4479 - accuracy: 0.8162
# Epoch 11/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4475 - accuracy: 0.8149
# Epoch 12/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4472 - accuracy: 0.8164
# Epoch 13/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4471 - accuracy: 0.8153
# Epoch 14/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4472 - accuracy: 0.8155
# Epoch 15/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4469 - accuracy: 0.8156
# Epoch 16/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4467 - accuracy: 0.8155
# Epoch 17/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4462 - accuracy: 0.8154
# Epoch 18/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4461 - accuracy: 0.8159
# Epoch 19/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4459 - accuracy: 0.8160
# Epoch 20/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4456 - accuracy: 0.8153
# Epoch 21/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4457 - accuracy: 0.8162
# Epoch 22/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4455 - accuracy: 0.8152
# Epoch 23/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4452 - accuracy: 0.8150
# Epoch 24/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4454 - accuracy: 0.8152
# Epoch 25/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4451 - accuracy: 0.8142
# Epoch 1/25
# 18648/18648 [==============================] - 2s 91us/step - loss: 0.5231 - accuracy: 0.7865
# Epoch 2/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4564 - accuracy: 0.8115
# Epoch 3/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4533 - accuracy: 0.8135
# Epoch 4/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4521 - accuracy: 0.8146
# Epoch 5/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4511 - accuracy: 0.8150
# Epoch 6/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4503 - accuracy: 0.8144
# Epoch 7/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4480 - accuracy: 0.8163
# Epoch 8/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.4459 - accuracy: 0.8162
# Epoch 9/25
# 18648/18648 [==============================] - ETA: 0s - loss: 0.4444 - accuracy: 0.81 - 2s 87us/step - loss: 0.4443 - accuracy: 0.8165
# Epoch 10/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4439 - accuracy: 0.8159
# Epoch 11/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4432 - accuracy: 0.8168
# Epoch 12/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4426 - accuracy: 0.8163
# Epoch 13/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4422 - accuracy: 0.8171
# Epoch 14/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4421 - accuracy: 0.8172
# Epoch 15/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4418 - accuracy: 0.8161
# Epoch 16/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4416 - accuracy: 0.8165
# Epoch 17/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4412 - accuracy: 0.8170
# Epoch 18/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4412 - accuracy: 0.8172
# Epoch 19/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4410 - accuracy: 0.8176
# Epoch 20/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4410 - accuracy: 0.8163
# Epoch 21/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4407 - accuracy: 0.8172
# Epoch 22/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4406 - accuracy: 0.8167
# Epoch 23/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4402 - accuracy: 0.8165
# Epoch 24/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4400 - accuracy: 0.8176
# Epoch 25/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4399 - accuracy: 0.8167
# Epoch 1/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.5208 - accuracy: 0.7810
# Epoch 2/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4548 - accuracy: 0.8125
# Epoch 3/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4504 - accuracy: 0.8152
# Epoch 4/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4492 - accuracy: 0.8164
# Epoch 5/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4482 - accuracy: 0.8162
# Epoch 6/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4477 - accuracy: 0.8163
# Epoch 7/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4473 - accuracy: 0.8171
# Epoch 8/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4473 - accuracy: 0.8183
# Epoch 9/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4470 - accuracy: 0.8170
# Epoch 10/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4467 - accuracy: 0.8170
# Epoch 11/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4468 - accuracy: 0.8176
# Epoch 12/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4466 - accuracy: 0.8167
# Epoch 13/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4465 - accuracy: 0.8169
# Epoch 14/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4461 - accuracy: 0.8171
# Epoch 15/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4460 - accuracy: 0.8169
# Epoch 16/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4460 - accuracy: 0.8170
# Epoch 17/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4458 - accuracy: 0.8176
# Epoch 18/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4454 - accuracy: 0.8184
# Epoch 19/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4456 - accuracy: 0.8182
# Epoch 20/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4450 - accuracy: 0.8185
# Epoch 21/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4450 - accuracy: 0.8174
# Epoch 22/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4449 - accuracy: 0.8173
# Epoch 23/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4442 - accuracy: 0.8173
# Epoch 24/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4435 - accuracy: 0.8181
# Epoch 25/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4429 - accuracy: 0.8197
# Epoch 1/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.5180 - accuracy: 0.7761
# Epoch 2/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4619 - accuracy: 0.7765
# Epoch 3/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4546 - accuracy: 0.8072
# Epoch 4/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4510 - accuracy: 0.8158
# Epoch 5/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4487 - accuracy: 0.8161
# Epoch 6/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4477 - accuracy: 0.8154
# Epoch 7/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4470 - accuracy: 0.8160
# Epoch 8/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4460 - accuracy: 0.8164
# Epoch 9/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4457 - accuracy: 0.8162
# Epoch 10/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4454 - accuracy: 0.8167
# Epoch 11/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4451 - accuracy: 0.8177
# Epoch 12/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4451 - accuracy: 0.8165
# Epoch 13/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4448 - accuracy: 0.8168
# Epoch 14/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4445 - accuracy: 0.8169
# Epoch 15/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4445 - accuracy: 0.8171
# Epoch 16/25
# 18648/18648 [==============================] - 2s 84us/step - loss: 0.4440 - accuracy: 0.8172
# Epoch 17/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4437 - accuracy: 0.8174
# Epoch 18/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4438 - accuracy: 0.8176
# Epoch 19/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4432 - accuracy: 0.8182
# Epoch 20/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4430 - accuracy: 0.8164
# Epoch 21/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4434 - accuracy: 0.8168
# Epoch 22/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4432 - accuracy: 0.8176
# Epoch 23/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4429 - accuracy: 0.8175
# Epoch 24/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4430 - accuracy: 0.8174
# Epoch 25/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4426 - accuracy: 0.8177
# Epoch 1/25
# 18648/18648 [==============================] - 2s 88us/step - loss: 0.5132 - accuracy: 0.7817
# Epoch 2/25
# 18648/18648 [==============================] - 2s 84us/step - loss: 0.4560 - accuracy: 0.8106
# Epoch 3/25
# 18648/18648 [==============================] - 2s 83us/step - loss: 0.4519 - accuracy: 0.8142
# Epoch 4/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4505 - accuracy: 0.8142
# Epoch 5/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4495 - accuracy: 0.8154
# Epoch 6/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4492 - accuracy: 0.8153
# Epoch 7/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4486 - accuracy: 0.8154
# Epoch 8/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4483 - accuracy: 0.8162
# Epoch 9/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4479 - accuracy: 0.8163
# Epoch 10/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4477 - accuracy: 0.8160
# Epoch 11/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4475 - accuracy: 0.8159
# Epoch 12/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4474 - accuracy: 0.8165
# Epoch 13/25
# 18648/18648 [==============================] - 2s 84us/step - loss: 0.4467 - accuracy: 0.8167
# Epoch 14/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4467 - accuracy: 0.8162
# Epoch 15/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4464 - accuracy: 0.8160
# Epoch 16/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4466 - accuracy: 0.8155
# Epoch 17/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4465 - accuracy: 0.8160
# Epoch 18/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4461 - accuracy: 0.8171
# Epoch 19/25
# 18648/18648 [==============================] - 2s 84us/step - loss: 0.4460 - accuracy: 0.8175
# Epoch 20/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4458 - accuracy: 0.8164
# Epoch 21/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4453 - accuracy: 0.8165
# Epoch 22/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4455 - accuracy: 0.8157
# Epoch 23/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4449 - accuracy: 0.8167
# Epoch 24/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4448 - accuracy: 0.8154
# Epoch 25/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4445 - accuracy: 0.8157
# Epoch 1/25
# 18648/18648 [==============================] - 2s 90us/step - loss: 0.5177 - accuracy: 0.7852
# Epoch 2/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4513 - accuracy: 0.8151
# Epoch 3/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4481 - accuracy: 0.8157
# Epoch 4/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4472 - accuracy: 0.8176
# Epoch 5/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4468 - accuracy: 0.8179
# Epoch 6/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4462 - accuracy: 0.8174
# Epoch 7/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4461 - accuracy: 0.8178
# Epoch 8/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4457 - accuracy: 0.8185
# Epoch 9/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4454 - accuracy: 0.8182
# Epoch 10/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4437 - accuracy: 0.8181
# Epoch 11/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4414 - accuracy: 0.8197
# Epoch 12/25
# 18648/18648 [==============================] - 2s 84us/step - loss: 0.4401 - accuracy: 0.8208
# Epoch 13/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4396 - accuracy: 0.8194
# Epoch 14/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4392 - accuracy: 0.8194
# Epoch 15/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4385 - accuracy: 0.8200
# Epoch 16/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4387 - accuracy: 0.8195
# Epoch 17/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4385 - accuracy: 0.8197
# Epoch 18/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4380 - accuracy: 0.8204
# Epoch 19/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4378 - accuracy: 0.8198
# Epoch 20/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4378 - accuracy: 0.8197
# Epoch 21/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4375 - accuracy: 0.8202
# Epoch 22/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4372 - accuracy: 0.8199
# Epoch 23/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4378 - accuracy: 0.8202
# Epoch 24/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4370 - accuracy: 0.8206
# Epoch 25/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4369 - accuracy: 0.8192
# Epoch 1/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.5361 - accuracy: 0.7738
# Epoch 2/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4879 - accuracy: 0.7739
# Epoch 3/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4811 - accuracy: 0.7739
# Epoch 4/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4764 - accuracy: 0.7894
# Epoch 5/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4746 - accuracy: 0.8013
# Epoch 6/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4733 - accuracy: 0.8041
# Epoch 7/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4727 - accuracy: 0.8066
# Epoch 8/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4719 - accuracy: 0.8067
# Epoch 9/25
# 18648/18648 [==============================] - 2s 82us/step - loss: 0.4722 - accuracy: 0.8084
# Epoch 10/25
# 18648/18648 [==============================] - 2s 82us/step - loss: 0.4718 - accuracy: 0.8074
# Epoch 11/25
# 18648/18648 [==============================] - 2s 83us/step - loss: 0.4719 - accuracy: 0.8079
# Epoch 12/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4714 - accuracy: 0.8089
# Epoch 13/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4713 - accuracy: 0.8098
# Epoch 14/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4714 - accuracy: 0.8090
# Epoch 15/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4712 - accuracy: 0.8101
# Epoch 16/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4713 - accuracy: 0.8077
# Epoch 17/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4712 - accuracy: 0.8090
# Epoch 18/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4712 - accuracy: 0.8085
# Epoch 19/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4711 - accuracy: 0.8101
# Epoch 20/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4713 - accuracy: 0.8085
# Epoch 21/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4711 - accuracy: 0.8083
# Epoch 22/25
# 18648/18648 [==============================] - 2s 87us/step - loss: 0.4712 - accuracy: 0.8089
# Epoch 23/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4710 - accuracy: 0.8095
# Epoch 24/25
# 18648/18648 [==============================] - 2s 86us/step - loss: 0.4710 - accuracy: 0.8094
# Epoch 25/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4710 - accuracy: 0.8083
# Epoch 1/25
# 18648/18648 [==============================] - 2s 89us/step - loss: 0.5329 - accuracy: 0.7877
# Epoch 2/25
# 18648/18648 [==============================] - 2s 85us/step - loss: 0.4568 - accuracy: 0.8106
# Epoch 3/25
# ...
# Epoch 27/50
# 18648/18648 [==============================] - 1s 48us/step - loss: 0.4705 - accuracy: 0.8086
# Epoch 28/50
# 18648/18648 [==============================] - 1s 49us/step - loss: 0.4706 - accuracy: 0.8097
# Epoch 29/50
# 18648/18648 [==============================] - 1s 48us/step - loss: 0.4707 - accuracy: 0.8088
# Epoch 30/50
# 18648/18648 [==============================] - 1s 50us/step - loss: 0.4707 - accuracy: 0.8090
# Epoch 31/50
# 18648/18648 [==============================] - 1s 49us/step - loss: 0.4707 - accuracy: 0.8098
# Epoch 32/50
# 18648/18648 [==============================] - 1s 53us/step - loss: 0.4703 - accuracy: 0.8089
# Epoch 33/50
# 18648/18648 [==============================] - 1s 51us/step - loss: 0.4705 - accuracy: 0.8095
# Epoch 34/50
# 18648/18648 [==============================] - 1s 49us/step - loss: 0.4707 - accuracy: 0.8104
# Epoch 35/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4704 - accuracy: 0.8101
# Epoch 36/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4706 - accuracy: 0.8085
# Epoch 37/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4705 - accuracy: 0.8090
# Epoch 38/50
# 18648/18648 [==============================] - 1s 47us/step - loss: 0.4704 - accuracy: 0.8101
# Epoch 39/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4702 - accuracy: 0.8093
# Epoch 40/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4704 - accuracy: 0.8087
# Epoch 41/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4705 - accuracy: 0.8096
# Epoch 42/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4705 - accuracy: 0.8094
# Epoch 43/50
# 18648/18648 [==============================] - 1s 47us/step - loss: 0.4704 - accuracy: 0.8100
# Epoch 44/50
# 18648/18648 [==============================] - 1s 48us/step - loss: 0.4702 - accuracy: 0.8096
# Epoch 45/50
# 18648/18648 [==============================] - 1s 48us/step - loss: 0.4702 - accuracy: 0.8095
# Epoch 46/50
# 18648/18648 [==============================] - 1s 50us/step - loss: 0.4704 - accuracy: 0.8111
# Epoch 47/50
# 18648/18648 [==============================] - 1s 48us/step - loss: 0.4703 - accuracy: 0.8094
# Epoch 48/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4703 - accuracy: 0.8100
# Epoch 49/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4700 - accuracy: 0.8094
# Epoch 50/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4701 - accuracy: 0.8102
# Epoch 1/50
# 18648/18648 [==============================] - 1s 51us/step - loss: 0.5637 - accuracy: 0.7748
# Epoch 2/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4621 - accuracy: 0.8040
# Epoch 3/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4512 - accuracy: 0.8155
# Epoch 4/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4491 - accuracy: 0.8164
# Epoch 5/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4481 - accuracy: 0.8176
# Epoch 6/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4474 - accuracy: 0.8170
# Epoch 7/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4469 - accuracy: 0.8174
# Epoch 8/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4464 - accuracy: 0.8178
# Epoch 9/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4465 - accuracy: 0.8176
# Epoch 10/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4461 - accuracy: 0.8178
# Epoch 11/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4457 - accuracy: 0.8181
# Epoch 12/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4457 - accuracy: 0.8177
# Epoch 13/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4453 - accuracy: 0.8179
# Epoch 14/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4451 - accuracy: 0.8181
# Epoch 15/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4447 - accuracy: 0.8173
# Epoch 16/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4439 - accuracy: 0.8181
# Epoch 17/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4420 - accuracy: 0.8182
# Epoch 18/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4406 - accuracy: 0.8183
# Epoch 19/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4398 - accuracy: 0.8193
# Epoch 20/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4392 - accuracy: 0.8194
# Epoch 21/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4388 - accuracy: 0.8194
# Epoch 22/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4385 - accuracy: 0.8200
# Epoch 23/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4383 - accuracy: 0.8198
# Epoch 24/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4380 - accuracy: 0.8190
# Epoch 25/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4377 - accuracy: 0.8208
# Epoch 26/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4371 - accuracy: 0.8205
# Epoch 27/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4369 - accuracy: 0.8201
# Epoch 28/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4368 - accuracy: 0.8206
# Epoch 29/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4366 - accuracy: 0.8208
# Epoch 30/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4362 - accuracy: 0.8202
# Epoch 31/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4361 - accuracy: 0.8206
# Epoch 32/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4359 - accuracy: 0.8200
# Epoch 33/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4359 - accuracy: 0.8191
# Epoch 34/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4355 - accuracy: 0.8208
# Epoch 35/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4357 - accuracy: 0.8197
# Epoch 36/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4353 - accuracy: 0.8200
# Epoch 37/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4354 - accuracy: 0.8204
# Epoch 38/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4351 - accuracy: 0.8202
# Epoch 39/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4351 - accuracy: 0.8199
# Epoch 40/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4347 - accuracy: 0.8199
# Epoch 41/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4348 - accuracy: 0.8199
# Epoch 42/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4345 - accuracy: 0.8199
# Epoch 43/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4347 - accuracy: 0.8199
# Epoch 44/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4344 - accuracy: 0.8197
# Epoch 45/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4345 - accuracy: 0.8204
# Epoch 46/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4340 - accuracy: 0.8198
# Epoch 47/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4340 - accuracy: 0.8201
# Epoch 48/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4342 - accuracy: 0.8197
# Epoch 49/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4339 - accuracy: 0.8202
# Epoch 50/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4338 - accuracy: 0.8207
# Epoch 1/50
# 18648/18648 [==============================] - 1s 50us/step - loss: 0.5545 - accuracy: 0.7762
# Epoch 2/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4881 - accuracy: 0.7762
# Epoch 3/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4814 - accuracy: 0.7762
# Epoch 4/50
# 18648/18648 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.77 - 1s 43us/step - loss: 0.4768 - accuracy: 0.7767
# Epoch 5/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4740 - accuracy: 0.7938
# Epoch 6/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4724 - accuracy: 0.8017
# Epoch 7/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4716 - accuracy: 0.8059
# Epoch 8/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4711 - accuracy: 0.8059
# Epoch 9/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4708 - accuracy: 0.8059
# Epoch 10/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4703 - accuracy: 0.8075
# Epoch 11/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4704 - accuracy: 0.8073
# Epoch 12/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4703 - accuracy: 0.8069
# Epoch 13/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4700 - accuracy: 0.8077
# Epoch 14/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4701 - accuracy: 0.8095
# Epoch 15/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4700 - accuracy: 0.8064
# Epoch 16/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4698 - accuracy: 0.8078
# Epoch 17/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4696 - accuracy: 0.8090
# Epoch 18/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4696 - accuracy: 0.8088
# Epoch 19/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4695 - accuracy: 0.8086
# Epoch 20/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4697 - accuracy: 0.8071
# Epoch 21/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4692 - accuracy: 0.8088
# Epoch 22/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4692 - accuracy: 0.8072
# Epoch 23/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4695 - accuracy: 0.8093
# Epoch 24/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4694 - accuracy: 0.8071
# Epoch 25/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4695 - accuracy: 0.8075
# Epoch 26/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4694 - accuracy: 0.8081
# Epoch 27/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4695 - accuracy: 0.8092
# Epoch 28/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4693 - accuracy: 0.8097
# Epoch 29/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4696 - accuracy: 0.8081
# Epoch 30/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4695 - accuracy: 0.8090
# Epoch 31/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4694 - accuracy: 0.8076
# Epoch 32/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4694 - accuracy: 0.8083
# Epoch 33/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4694 - accuracy: 0.8102
# Epoch 34/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4691 - accuracy: 0.8088
# Epoch 35/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4692 - accuracy: 0.8070
# Epoch 36/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4695 - accuracy: 0.8091
# Epoch 37/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4693 - accuracy: 0.8091
# Epoch 38/50
# 18648/18648 [==============================] - 1s 48us/step - loss: 0.4694 - accuracy: 0.8089
# Epoch 39/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4694 - accuracy: 0.8078
# Epoch 40/50
# 18648/18648 [==============================] - 1s 46us/step - loss: 0.4696 - accuracy: 0.8087
# Epoch 41/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4692 - accuracy: 0.8098
# Epoch 42/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4692 - accuracy: 0.8079
# Epoch 43/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4694 - accuracy: 0.8093
# Epoch 44/50
# 18648/18648 [==============================] - 1s 43us/step - loss: 0.4690 - accuracy: 0.8088
# Epoch 45/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4692 - accuracy: 0.8080
# Epoch 46/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4695 - accuracy: 0.8084
# Epoch 47/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4693 - accuracy: 0.8084
# Epoch 48/50
# 18648/18648 [==============================] - 1s 44us/step - loss: 0.4691 - accuracy: 0.8093
# Epoch 49/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4690 - accuracy: 0.8087
# Epoch 50/50
# 18648/18648 [==============================] - 1s 45us/step - loss: 0.4691 - accuracy: 0.8100
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed: 63.1min finished
# Epoch 1/25
# 20720/20720 [==============================] - 1s 47us/step - loss: 0.5587 - accuracy: 0.7803
# Epoch 2/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4602 - accuracy: 0.8093
# Epoch 3/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4525 - accuracy: 0.8130
# Epoch 4/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4507 - accuracy: 0.8147
# Epoch 5/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4497 - accuracy: 0.8156
# Epoch 6/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4491 - accuracy: 0.8168
# Epoch 7/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4483 - accuracy: 0.8172
# Epoch 8/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4482 - accuracy: 0.8163
# Epoch 9/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4477 - accuracy: 0.8169
# Epoch 10/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4475 - accuracy: 0.8166
# Epoch 11/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4472 - accuracy: 0.8170
# Epoch 12/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4469 - accuracy: 0.8171
# Epoch 13/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4467 - accuracy: 0.8173
# Epoch 14/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4463 - accuracy: 0.8173
# Epoch 15/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4463 - accuracy: 0.8163
# Epoch 16/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4461 - accuracy: 0.8172
# Epoch 17/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4452 - accuracy: 0.8179
# Epoch 18/25
# 20720/20720 [==============================] - 1s 43us/step - loss: 0.4436 - accuracy: 0.8178
# Epoch 19/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4414 - accuracy: 0.8176
# Epoch 20/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4404 - accuracy: 0.8180
# Epoch 21/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4399 - accuracy: 0.8190
# Epoch 22/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4393 - accuracy: 0.8181
# Epoch 23/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4391 - accuracy: 0.8185
# Epoch 24/25
# 20720/20720 [==============================] - 1s 45us/step - loss: 0.4390 - accuracy: 0.8181
# Epoch 25/25
# 20720/20720 [==============================] - 1s 44us/step - loss: 0.4385 - accuracy: 0.8186
# Best Parameters
# {'batch_size': 50, 'epochs': 25, 'optimizer': 'rmsprop'}
# Best Accuracy
# 0.8167471042471043

# %%
# Now to get the best selection of parameters and best accuracy
print("Best Parameters")
best_params = grid_search.best_params_
print(best_params)
print("Best Accuracy")
best_accuracy=grid_search.best_score_
print(best_accuracy)
# Out:
# Best Parameters
# {'batch_size': 50, 'epochs': 25, 'optimizer': 'rmsprop'}
# Best Accuracy
# 0.8167471042471043
