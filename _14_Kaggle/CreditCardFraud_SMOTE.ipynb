# %% [markdown]
# # Credit Card fraud - With Synthetic Minority Oversampling Technique
#
# **Context**<br>
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# **Content**<br>
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.<br>
#
# **Inspiration**<br>
# Identify fraudulent credit card transactions.
# <br><br>
# Given the class imbalance ratio, we recommend measuring the accuracy using the Area Under the Precision-Recall Curve (AUPRC).
# Confusion matrix accuracy is not meaningful for unbalanced classification.

# %% [markdown]
# ## Library imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

import tensorflow as tf

# %% [markdown]
# ## Load the dataset and Validate Data Load

# %%
# Load the dataset 

creditcard = pd.read_csv("../../../LargeDatasets/creditcard.csv")

creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Lets Check the data structure
creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Check for any missing values
creditcard.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Explore the response variable

plt.figure(figsize=(10, 6))
sns.countplot(x='Class', data=creditcard)
plt.grid()
plt.title("Distribution of the target Variable")

# Value Counts
print(creditcard['Class'].value_counts())
print(f"Fraud Transactions are - {len(creditcard[creditcard['Class'] == 1])/len(creditcard) * 100} % of Total")
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64
# Fraud Transactions are - 0.1727485630620034 % of Total

# %%
# We would see the interaction between V1 and V2

plt.figure(figsize=(10, 6))
sns.scatterplot(x="V1", y="V2", hue="Class", data=creditcard)
# Out:
# <AxesSubplot:xlabel='V1', ylabel='V2'>

# %%
# We would observe the interaction between V5 and V6 through lmplot
plt.figure(figsize=(10, 6))
sns.lmplot(x="V5", y="V6", hue="Class", data=creditcard, fit_reg=False)

# %%
# Taking two more attributes
sns.lmplot(x="V15", y="V16", hue='Class', data=creditcard, fit_reg=False)

# %% [markdown]
# #### Each of the above plot shows that fraudulent transactions are more or less concentrated at one place

# %%
# We will introduce a log of the Amount column, use the column in modelling and drop the original Amount column
# However in order to do this, there are some values with 0 in Amount and Log(0) is infinity and hence we add a very small
# negligible amount to the log to avoid this infinity error

adjustments = 0.001

creditcard['Log Amount'] = np.log(creditcard['Amount'] + adjustments)

# %%
sns.displot(x="Log Amount", hue='Class', data=creditcard)

# %% [markdown]
# ## Train Test Split and Feature Scaling

# %%
# Dropping Columns like Time, Amount

creditcard = creditcard.drop(labels=["Time", "Amount"], axis=1)

# %%
# Extracting features and target

features = creditcard.drop(labels=['Class'], axis = 1)
target = creditcard['Class']

# %%
# Perform feature scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
features = sc.fit_transform(features)
features
# Out:
# array([[-0.69424232, -0.04407492,  1.6727735 , ...,  0.33089162,
#         -0.06378115,  1.02091976],
#        [ 0.60849633,  0.16117592,  0.1097971 , ..., -0.02225568,
#          0.04460752, -0.96466543],
#        [-0.69350046, -0.81157783,  1.16946849, ..., -0.13713686,
#         -0.18102083,  1.47975471],
#        ...,
#        [ 0.98002374, -0.18243372, -2.14320514, ...,  0.01103672,
#         -0.0804672 ,  0.63036959],
#        [-0.12275539,  0.32125034,  0.46332013, ...,  0.26960398,
#          0.31668678, -0.31596056],
#        [-0.27233093, -0.11489898,  0.46386564, ..., -0.00598394,
#          0.04134999,  1.20464259]])

# %%
# Perform the training, validation and test splits

from sklearn.model_selection import train_test_split
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.3, 
                                                                            random_state=101, stratify=target)

features_train, features_validation, target_train, target_validation = train_test_split(features_train, target_train,
                                                                                        test_size=0.3, random_state=101, 
                                                                                        stratify=target_train)

# %%
print("Training Features shape: ", features_train.shape)
print("Training Target shape: ", target_train.shape)

print("Validation Features shape: ", features_validation.shape)
print("Validation Target shape: ", target_validation.shape)

print("Test Features shape: ", features_test.shape)
print("Training Target shape: ", target_test.shape)
# Out:
# Training Features shape:  (139554, 29)
# Training Target shape:  (139554,)
# Validation Features shape:  (59810, 29)
# Validation Target shape:  (59810,)
# Test Features shape:  (85443, 29)
# Training Target shape:  (85443,)

# %% [markdown]
# ## Build and Train the Neural Network Model

# %%
# Define the Model Constants

INPUT_SHAPE = (features_train.shape[1], )

OUTPUT_UNITS = 1
HIDDEN_UNITS = 16
ACTIVATION_HIDDEN = tf.keras.activations.relu
ACTIVATION_OUTPUT = tf.keras.activations.sigmoid
LEARNING_RATE = 1e-3
OPTIMIZER = tf.keras.optimizers.Adam(LEARNING_RATE)
LOSS_FUNCTION = tf.keras.losses.BinaryCrossentropy()
DROPOUT_RATE = 0.5

EPOCHS = 100
BATCH_SIZE = 2048

# %% [markdown]
# **Model is fit using a larger than default batch size.. We train with a size of 2048, this is important to ensure that each batch has a decent chance of containing a few positive samples. If the batch size was too small, they would likely have no fraudulent transactions to learn from.**

# %%
# Define the Metrics

METRICS = [tf.keras.metrics.TruePositives(name='tp'),
          tf.keras.metrics.FalsePositives(name='fp'),
          tf.keras.metrics.TrueNegatives(name='tn'),
          tf.keras.metrics.FalseNegatives(name='fn'), 
          tf.keras.metrics.BinaryAccuracy(name='accuracy'),
          tf.keras.metrics.Precision(name='precision'),
          tf.keras.metrics.Recall(name='recall'),
          tf.keras.metrics.AUC(name='auc')]

# %% [markdown]
# #### Function to build and compile the model

# %% [markdown]
# #### Understanding Useful Metrics
#
# Note that there are a few metrics defined below that can be computed by the model that will be helpful when evaluating the performance.
#
# <img src="resources/classification-metrics.png" length=800 width=800>

# %%
# Function which will build and compile the model

def make_model(metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)
    model = tf.keras.models.Sequential([
           tf.keras.layers.Dense(input_shape=INPUT_SHAPE, units=HIDDEN_UNITS, activation=ACTIVATION_HIDDEN),
           tf.keras.layers.Dropout(DROPOUT_RATE),
           tf.keras.layers.Dense(units=OUTPUT_UNITS, activation=ACTIVATION_OUTPUT, bias_initializer=output_bias)
       ])
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=metrics)
    return model

# %%
# Lets build the model and see the mmodel summary

model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                480
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________

# %%
# we will now train the model on training and validation data

epochs_history = model.fit(features_train, target_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
                          validation_data=(features_validation, target_validation),
                          verbose=1)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 1s 16ms/step - loss: 0.6259 - tp: 49.0000 - fp: 49193.0000 - tn: 90120.0000 - fn: 192.0000 - accuracy: 0.6461 - precision: 9.9509e-04 - recall: 0.2033 - auc: 0.2362 - val_loss: 0.3807 - val_tp: 1.0000 - val_fp: 1900.0000 - val_tn: 57807.0000 - val_fn: 102.0000 - val_accuracy: 0.9665 - val_precision: 5.2604e-04 - val_recall: 0.0097 - val_auc: 0.0672
# Epoch 2/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.3598 - tp: 40.0000 - fp: 18777.0000 - tn: 120536.0000 - fn: 201.0000 - accuracy: 0.8640 - precision: 0.0021 - recall: 0.1660 - auc: 0.3466 - val_loss: 0.2031 - val_tp: 0.0000e+00 - val_fp: 37.0000 - val_tn: 59670.0000 - val_fn: 103.0000 - val_accuracy: 0.9977 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1345
# Epoch 3/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.2353 - tp: 46.0000 - fp: 7247.0000 - tn: 132066.0000 - fn: 195.0000 - accuracy: 0.9467 - precision: 0.0063 - recall: 0.1909 - auc: 0.4328 - val_loss: 0.1145 - val_tp: 0.0000e+00 - val_fp: 4.0000 - val_tn: 59703.0000 - val_fn: 103.0000 - val_accuracy: 0.9982 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5596
# Epoch 4/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.1670 - tp: 62.0000 - fp: 3562.0000 - tn: 135751.0000 - fn: 179.0000 - accuracy: 0.9732 - precision: 0.0171 - recall: 0.2573 - auc: 0.6244 - val_loss: 0.0680 - val_tp: 26.0000 - val_fp: 10.0000 - val_tn: 59697.0000 - val_fn: 77.0000 - val_accuracy: 0.9985 - val_precision: 0.7222 - val_recall: 0.2524 - val_auc: 0.8288
# Epoch 5/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.1253 - tp: 79.0000 - fp: 1874.0000 - tn: 137439.0000 - fn: 162.0000 - accuracy: 0.9854 - precision: 0.0405 - recall: 0.3278 - auc: 0.7368 - val_loss: 0.0429 - val_tp: 47.0000 - val_fp: 10.0000 - val_tn: 59697.0000 - val_fn: 56.0000 - val_accuracy: 0.9989 - val_precision: 0.8246 - val_recall: 0.4563 - val_auc: 0.8769
# Epoch 6/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.1001 - tp: 103.0000 - fp: 997.0000 - tn: 138316.0000 - fn: 138.0000 - accuracy: 0.9919 - precision: 0.0936 - recall: 0.4274 - auc: 0.7866 - val_loss: 0.0284 - val_tp: 54.0000 - val_fp: 10.0000 - val_tn: 59697.0000 - val_fn: 49.0000 - val_accuracy: 0.9990 - val_precision: 0.8438 - val_recall: 0.5243 - val_auc: 0.8993
# Epoch 7/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0810 - tp: 121.0000 - fp: 623.0000 - tn: 138690.0000 - fn: 120.0000 - accuracy: 0.9947 - precision: 0.1626 - recall: 0.5021 - auc: 0.8203 - val_loss: 0.0199 - val_tp: 59.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 44.0000 - val_accuracy: 0.9991 - val_precision: 0.8310 - val_recall: 0.5728 - val_auc: 0.9096
# Epoch 8/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0688 - tp: 118.0000 - fp: 295.0000 - tn: 139018.0000 - fn: 123.0000 - accuracy: 0.9970 - precision: 0.2857 - recall: 0.4896 - auc: 0.8359 - val_loss: 0.0147 - val_tp: 61.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 42.0000 - val_accuracy: 0.9991 - val_precision: 0.8356 - val_recall: 0.5922 - val_auc: 0.9200
# Epoch 9/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0594 - tp: 125.0000 - fp: 149.0000 - tn: 139164.0000 - fn: 116.0000 - accuracy: 0.9981 - precision: 0.4562 - recall: 0.5187 - auc: 0.8470 - val_loss: 0.0113 - val_tp: 60.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 43.0000 - val_accuracy: 0.9991 - val_precision: 0.8333 - val_recall: 0.5825 - val_auc: 0.9287
# Epoch 10/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0518 - tp: 120.0000 - fp: 87.0000 - tn: 139226.0000 - fn: 121.0000 - accuracy: 0.9985 - precision: 0.5797 - recall: 0.4979 - auc: 0.8725 - val_loss: 0.0091 - val_tp: 66.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 37.0000 - val_accuracy: 0.9992 - val_precision: 0.8462 - val_recall: 0.6408 - val_auc: 0.9243
# Epoch 11/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0465 - tp: 126.0000 - fp: 47.0000 - tn: 139266.0000 - fn: 115.0000 - accuracy: 0.9988 - precision: 0.7283 - recall: 0.5228 - auc: 0.8666 - val_loss: 0.0075 - val_tp: 66.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 37.0000 - val_accuracy: 0.9992 - val_precision: 0.8462 - val_recall: 0.6408 - val_auc: 0.9359
# Epoch 12/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0408 - tp: 132.0000 - fp: 36.0000 - tn: 139277.0000 - fn: 109.0000 - accuracy: 0.9990 - precision: 0.7857 - recall: 0.5477 - auc: 0.8766 - val_loss: 0.0065 - val_tp: 66.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 37.0000 - val_accuracy: 0.9992 - val_precision: 0.8462 - val_recall: 0.6408 - val_auc: 0.9434
# Epoch 13/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0373 - tp: 149.0000 - fp: 28.0000 - tn: 139285.0000 - fn: 92.0000 - accuracy: 0.9991 - precision: 0.8418 - recall: 0.6183 - auc: 0.8818 - val_loss: 0.0057 - val_tp: 70.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 33.0000 - val_accuracy: 0.9992 - val_precision: 0.8537 - val_recall: 0.6796 - val_auc: 0.9429
# Epoch 14/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0346 - tp: 142.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 99.0000 - accuracy: 0.9991 - precision: 0.8554 - recall: 0.5892 - auc: 0.8866 - val_loss: 0.0052 - val_tp: 69.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 34.0000 - val_accuracy: 0.9992 - val_precision: 0.8519 - val_recall: 0.6699 - val_auc: 0.9362
# Epoch 15/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0320 - tp: 146.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 95.0000 - accuracy: 0.9992 - precision: 0.8743 - recall: 0.6058 - auc: 0.8951 - val_loss: 0.0048 - val_tp: 71.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 32.0000 - val_accuracy: 0.9993 - val_precision: 0.8554 - val_recall: 0.6893 - val_auc: 0.9383
# Epoch 16/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0297 - tp: 146.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 95.0000 - accuracy: 0.9992 - precision: 0.8743 - recall: 0.6058 - auc: 0.8819 - val_loss: 0.0045 - val_tp: 73.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 30.0000 - val_accuracy: 0.9993 - val_precision: 0.8588 - val_recall: 0.7087 - val_auc: 0.9393
# Epoch 17/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0271 - tp: 145.0000 - fp: 18.0000 - tn: 139295.0000 - fn: 96.0000 - accuracy: 0.9992 - precision: 0.8896 - recall: 0.6017 - auc: 0.9000 - val_loss: 0.0043 - val_tp: 74.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 29.0000 - val_accuracy: 0.9993 - val_precision: 0.8605 - val_recall: 0.7184 - val_auc: 0.9351
# Epoch 18/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0259 - tp: 151.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 90.0000 - accuracy: 0.9992 - precision: 0.8728 - recall: 0.6266 - auc: 0.8956 - val_loss: 0.0041 - val_tp: 74.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 29.0000 - val_accuracy: 0.9993 - val_precision: 0.8605 - val_recall: 0.7184 - val_auc: 0.9355
# Epoch 19/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0242 - tp: 155.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 86.0000 - accuracy: 0.9992 - precision: 0.8857 - recall: 0.6432 - auc: 0.8953 - val_loss: 0.0040 - val_tp: 74.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 29.0000 - val_accuracy: 0.9993 - val_precision: 0.8605 - val_recall: 0.7184 - val_auc: 0.9359
# Epoch 20/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0228 - tp: 153.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 88.0000 - accuracy: 0.9992 - precision: 0.8693 - recall: 0.6349 - auc: 0.9004 - val_loss: 0.0039 - val_tp: 74.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 29.0000 - val_accuracy: 0.9993 - val_precision: 0.8605 - val_recall: 0.7184 - val_auc: 0.9312
# Epoch 21/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0216 - tp: 162.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 79.0000 - accuracy: 0.9993 - precision: 0.8804 - recall: 0.6722 - auc: 0.8966 - val_loss: 0.0038 - val_tp: 74.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 29.0000 - val_accuracy: 0.9993 - val_precision: 0.8605 - val_recall: 0.7184 - val_auc: 0.9314
# Epoch 22/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0206 - tp: 163.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 78.0000 - accuracy: 0.9993 - precision: 0.8811 - recall: 0.6763 - auc: 0.8985 - val_loss: 0.0038 - val_tp: 77.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 26.0000 - val_accuracy: 0.9994 - val_precision: 0.8652 - val_recall: 0.7476 - val_auc: 0.9315
# Epoch 23/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0194 - tp: 163.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 78.0000 - accuracy: 0.9993 - precision: 0.8670 - recall: 0.6763 - auc: 0.9111 - val_loss: 0.0038 - val_tp: 78.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 25.0000 - val_accuracy: 0.9994 - val_precision: 0.8667 - val_recall: 0.7573 - val_auc: 0.9316
# Epoch 24/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0185 - tp: 161.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8750 - recall: 0.6680 - auc: 0.9032 - val_loss: 0.0037 - val_tp: 78.0000 - val_fp: 12.0000 - val_tn: 59695.0000 - val_fn: 25.0000 - val_accuracy: 0.9994 - val_precision: 0.8667 - val_recall: 0.7573 - val_auc: 0.9316
# Epoch 25/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0180 - tp: 163.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 78.0000 - accuracy: 0.9993 - precision: 0.8859 - recall: 0.6763 - auc: 0.9131 - val_loss: 0.0037 - val_tp: 79.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 24.0000 - val_accuracy: 0.9994 - val_precision: 0.8587 - val_recall: 0.7670 - val_auc: 0.9317
# Epoch 26/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0171 - tp: 164.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8817 - recall: 0.6805 - auc: 0.9120 - val_loss: 0.0037 - val_tp: 79.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 24.0000 - val_accuracy: 0.9994 - val_precision: 0.8587 - val_recall: 0.7670 - val_auc: 0.9317
# Epoch 27/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0165 - tp: 164.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8913 - recall: 0.6805 - auc: 0.9085 - val_loss: 0.0037 - val_tp: 79.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 24.0000 - val_accuracy: 0.9994 - val_precision: 0.8587 - val_recall: 0.7670 - val_auc: 0.9317
# Epoch 28/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0156 - tp: 166.0000 - fp: 28.0000 - tn: 139285.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8557 - recall: 0.6888 - auc: 0.9029 - val_loss: 0.0037 - val_tp: 79.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 24.0000 - val_accuracy: 0.9994 - val_precision: 0.8587 - val_recall: 0.7670 - val_auc: 0.9317
# Epoch 29/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0157 - tp: 166.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8737 - recall: 0.6888 - auc: 0.9138 - val_loss: 0.0037 - val_tp: 80.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 23.0000 - val_accuracy: 0.9994 - val_precision: 0.8602 - val_recall: 0.7767 - val_auc: 0.9317
# Epoch 30/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0146 - tp: 172.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 69.0000 - accuracy: 0.9993 - precision: 0.8776 - recall: 0.7137 - auc: 0.9110 - val_loss: 0.0037 - val_tp: 80.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 23.0000 - val_accuracy: 0.9994 - val_precision: 0.8602 - val_recall: 0.7767 - val_auc: 0.9317
# Epoch 31/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0141 - tp: 158.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 83.0000 - accuracy: 0.9992 - precision: 0.8778 - recall: 0.6556 - auc: 0.9102 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 32/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0138 - tp: 161.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8798 - recall: 0.6680 - auc: 0.9180 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 33/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0137 - tp: 162.0000 - fp: 26.0000 - tn: 139287.0000 - fn: 79.0000 - accuracy: 0.9992 - precision: 0.8617 - recall: 0.6722 - auc: 0.9088 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 34/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0131 - tp: 162.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 79.0000 - accuracy: 0.9993 - precision: 0.8663 - recall: 0.6722 - auc: 0.9158 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 35/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0124 - tp: 171.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 70.0000 - accuracy: 0.9993 - precision: 0.8724 - recall: 0.7095 - auc: 0.9232 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 36/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0120 - tp: 159.0000 - fp: 26.0000 - tn: 139287.0000 - fn: 82.0000 - accuracy: 0.9992 - precision: 0.8595 - recall: 0.6598 - auc: 0.9266 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 37/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0121 - tp: 164.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8677 - recall: 0.6805 - auc: 0.9115 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 38/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0112 - tp: 166.0000 - fp: 26.0000 - tn: 139287.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8646 - recall: 0.6888 - auc: 0.9243 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 39/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0112 - tp: 162.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 79.0000 - accuracy: 0.9993 - precision: 0.8901 - recall: 0.6722 - auc: 0.9243 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 40/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0106 - tp: 169.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 72.0000 - accuracy: 0.9993 - precision: 0.8802 - recall: 0.7012 - auc: 0.9154 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 41/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0104 - tp: 164.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8677 - recall: 0.6805 - auc: 0.9241 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 42/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0106 - tp: 157.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 84.0000 - accuracy: 0.9992 - precision: 0.8626 - recall: 0.6515 - auc: 0.9196 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 43/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0101 - tp: 170.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 71.0000 - accuracy: 0.9993 - precision: 0.8854 - recall: 0.7054 - auc: 0.9240 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 44/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0095 - tp: 161.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8798 - recall: 0.6680 - auc: 0.9235 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 45/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0097 - tp: 167.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 74.0000 - accuracy: 0.9993 - precision: 0.8743 - recall: 0.6929 - auc: 0.9193 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 46/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0093 - tp: 174.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 67.0000 - accuracy: 0.9994 - precision: 0.8832 - recall: 0.7220 - auc: 0.9255 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 47/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0092 - tp: 166.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8737 - recall: 0.6888 - auc: 0.9254 - val_loss: 0.0037 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 48/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0093 - tp: 161.0000 - fp: 29.0000 - tn: 139284.0000 - fn: 80.0000 - accuracy: 0.9992 - precision: 0.8474 - recall: 0.6680 - auc: 0.9170 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 49/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0089 - tp: 164.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8677 - recall: 0.6805 - auc: 0.9242 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 50/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0085 - tp: 168.0000 - fp: 26.0000 - tn: 139287.0000 - fn: 73.0000 - accuracy: 0.9993 - precision: 0.8660 - recall: 0.6971 - auc: 0.9322 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 51/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0088 - tp: 165.0000 - fp: 26.0000 - tn: 139287.0000 - fn: 76.0000 - accuracy: 0.9993 - precision: 0.8639 - recall: 0.6846 - auc: 0.9311 - val_loss: 0.0038 - val_tp: 81.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 22.0000 - val_accuracy: 0.9994 - val_precision: 0.8526 - val_recall: 0.7864 - val_auc: 0.9318
# Epoch 52/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0082 - tp: 169.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 72.0000 - accuracy: 0.9993 - precision: 0.8802 - recall: 0.7012 - auc: 0.9228 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 53/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0084 - tp: 161.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8750 - recall: 0.6680 - auc: 0.9314 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 54/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0087 - tp: 158.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 83.0000 - accuracy: 0.9993 - precision: 0.8876 - recall: 0.6556 - auc: 0.9205 - val_loss: 0.0038 - val_tp: 81.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 22.0000 - val_accuracy: 0.9994 - val_precision: 0.8526 - val_recall: 0.7864 - val_auc: 0.9317
# Epoch 55/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0082 - tp: 166.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8925 - recall: 0.6888 - auc: 0.9313 - val_loss: 0.0038 - val_tp: 81.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 22.0000 - val_accuracy: 0.9994 - val_precision: 0.8617 - val_recall: 0.7864 - val_auc: 0.9317
# Epoch 56/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0078 - tp: 169.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 72.0000 - accuracy: 0.9993 - precision: 0.8802 - recall: 0.7012 - auc: 0.9280 - val_loss: 0.0039 - val_tp: 81.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 22.0000 - val_accuracy: 0.9994 - val_precision: 0.8617 - val_recall: 0.7864 - val_auc: 0.9317
# Epoch 57/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0078 - tp: 166.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8783 - recall: 0.6888 - auc: 0.9320 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 58/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0081 - tp: 166.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8737 - recall: 0.6888 - auc: 0.9319 - val_loss: 0.0038 - val_tp: 81.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 22.0000 - val_accuracy: 0.9994 - val_precision: 0.8617 - val_recall: 0.7864 - val_auc: 0.9317
# Epoch 59/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0080 - tp: 161.0000 - fp: 19.0000 - tn: 139294.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8944 - recall: 0.6680 - auc: 0.9278 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 60/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0075 - tp: 172.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 69.0000 - accuracy: 0.9993 - precision: 0.8776 - recall: 0.7137 - auc: 0.9262 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 61/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0073 - tp: 164.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8677 - recall: 0.6805 - auc: 0.9371 - val_loss: 0.0039 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 62/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0071 - tp: 170.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 71.0000 - accuracy: 0.9993 - precision: 0.8808 - recall: 0.7054 - auc: 0.9306 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 63/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0075 - tp: 165.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 76.0000 - accuracy: 0.9993 - precision: 0.8730 - recall: 0.6846 - auc: 0.9347 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9318
# Epoch 64/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0068 - tp: 161.0000 - fp: 27.0000 - tn: 139286.0000 - fn: 80.0000 - accuracy: 0.9992 - precision: 0.8564 - recall: 0.6680 - auc: 0.9350 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 65/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0071 - tp: 167.0000 - fp: 28.0000 - tn: 139285.0000 - fn: 74.0000 - accuracy: 0.9993 - precision: 0.8564 - recall: 0.6929 - auc: 0.9289 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 66/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0071 - tp: 166.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8830 - recall: 0.6888 - auc: 0.9309 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 67/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0068 - tp: 159.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 82.0000 - accuracy: 0.9992 - precision: 0.8689 - recall: 0.6598 - auc: 0.9357 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 68/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0072 - tp: 163.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 78.0000 - accuracy: 0.9993 - precision: 0.8670 - recall: 0.6763 - auc: 0.9294 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 69/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0065 - tp: 161.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8798 - recall: 0.6680 - auc: 0.9399 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 70/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0069 - tp: 160.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 81.0000 - accuracy: 0.9993 - precision: 0.8743 - recall: 0.6639 - auc: 0.9336 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 71/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0064 - tp: 160.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 81.0000 - accuracy: 0.9993 - precision: 0.8889 - recall: 0.6639 - auc: 0.9420 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 72/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0064 - tp: 165.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 76.0000 - accuracy: 0.9993 - precision: 0.8730 - recall: 0.6846 - auc: 0.9359 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 73/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0065 - tp: 169.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 72.0000 - accuracy: 0.9993 - precision: 0.8756 - recall: 0.7012 - auc: 0.9318 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 74/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0063 - tp: 170.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 71.0000 - accuracy: 0.9993 - precision: 0.8808 - recall: 0.7054 - auc: 0.9358 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9317
# Epoch 75/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0062 - tp: 158.0000 - fp: 19.0000 - tn: 139294.0000 - fn: 83.0000 - accuracy: 0.9993 - precision: 0.8927 - recall: 0.6556 - auc: 0.9343 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9365
# Epoch 76/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0061 - tp: 156.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 85.0000 - accuracy: 0.9992 - precision: 0.8619 - recall: 0.6473 - auc: 0.9341 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9365
# Epoch 77/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0064 - tp: 153.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 88.0000 - accuracy: 0.9992 - precision: 0.8693 - recall: 0.6349 - auc: 0.9320 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9365
# Epoch 78/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0060 - tp: 157.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 84.0000 - accuracy: 0.9992 - precision: 0.8771 - recall: 0.6515 - auc: 0.9469 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9365
# Epoch 79/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0059 - tp: 164.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 77.0000 - accuracy: 0.9993 - precision: 0.8817 - recall: 0.6805 - auc: 0.9383 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9366
# Epoch 80/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0060 - tp: 161.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8703 - recall: 0.6680 - auc: 0.9384 - val_loss: 0.0039 - val_tp: 82.0000 - val_fp: 13.0000 - val_tn: 59694.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8632 - val_recall: 0.7961 - val_auc: 0.9366
# Epoch 81/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0060 - tp: 155.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 86.0000 - accuracy: 0.9992 - precision: 0.8659 - recall: 0.6432 - auc: 0.9324 - val_loss: 0.0039 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9366
# Epoch 82/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0055 - tp: 166.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 75.0000 - accuracy: 0.9993 - precision: 0.8925 - recall: 0.6888 - auc: 0.9512 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9366
# Epoch 83/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0056 - tp: 165.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 76.0000 - accuracy: 0.9993 - precision: 0.8871 - recall: 0.6846 - auc: 0.9367 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9366
# Epoch 84/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0057 - tp: 157.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 84.0000 - accuracy: 0.9992 - precision: 0.8674 - recall: 0.6515 - auc: 0.9367 - val_loss: 0.0039 - val_tp: 84.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 19.0000 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8155 - val_auc: 0.9366
# Epoch 85/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0058 - tp: 157.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 84.0000 - accuracy: 0.9992 - precision: 0.8820 - recall: 0.6515 - auc: 0.9430 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9365
# Epoch 86/100
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0055 - tp: 160.0000 - fp: 17.0000 - tn: 139296.0000 - fn: 81.0000 - accuracy: 0.9993 - precision: 0.9040 - recall: 0.6639 - auc: 0.9451 - val_loss: 0.0039 - val_tp: 84.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 19.0000 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8155 - val_auc: 0.9365
# Epoch 87/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0055 - tp: 160.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 81.0000 - accuracy: 0.9992 - precision: 0.8649 - recall: 0.6639 - auc: 0.9454 - val_loss: 0.0039 - val_tp: 84.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 19.0000 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8155 - val_auc: 0.9366
# Epoch 88/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0057 - tp: 162.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 79.0000 - accuracy: 0.9993 - precision: 0.8757 - recall: 0.6722 - auc: 0.9390 - val_loss: 0.0039 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9366
# Epoch 89/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0054 - tp: 162.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 79.0000 - accuracy: 0.9993 - precision: 0.8757 - recall: 0.6722 - auc: 0.9370 - val_loss: 0.0038 - val_tp: 84.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 19.0000 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8155 - val_auc: 0.9317
# Epoch 90/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0055 - tp: 172.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 69.0000 - accuracy: 0.9994 - precision: 0.8958 - recall: 0.7137 - auc: 0.9432 - val_loss: 0.0039 - val_tp: 84.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 19.0000 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8155 - val_auc: 0.9365
# Epoch 91/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0058 - tp: 149.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 92.0000 - accuracy: 0.9992 - precision: 0.8765 - recall: 0.6183 - auc: 0.9348 - val_loss: 0.0038 - val_tp: 82.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 21.0000 - val_accuracy: 0.9994 - val_precision: 0.8542 - val_recall: 0.7961 - val_auc: 0.9365
# Epoch 92/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0053 - tp: 150.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 91.0000 - accuracy: 0.9992 - precision: 0.8772 - recall: 0.6224 - auc: 0.9350 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9365
# Epoch 93/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0054 - tp: 156.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 85.0000 - accuracy: 0.9992 - precision: 0.8864 - recall: 0.6473 - auc: 0.9350 - val_loss: 0.0038 - val_tp: 81.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 22.0000 - val_accuracy: 0.9994 - val_precision: 0.8526 - val_recall: 0.7864 - val_auc: 0.9365
# Epoch 94/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0053 - tp: 151.0000 - fp: 21.0000 - tn: 139292.0000 - fn: 90.0000 - accuracy: 0.9992 - precision: 0.8779 - recall: 0.6266 - auc: 0.9434 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9366
# Epoch 95/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0053 - tp: 160.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 81.0000 - accuracy: 0.9993 - precision: 0.8791 - recall: 0.6639 - auc: 0.9351 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 96/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0053 - tp: 156.0000 - fp: 23.0000 - tn: 139290.0000 - fn: 85.0000 - accuracy: 0.9992 - precision: 0.8715 - recall: 0.6473 - auc: 0.9351 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9317
# Epoch 97/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0052 - tp: 160.0000 - fp: 22.0000 - tn: 139291.0000 - fn: 81.0000 - accuracy: 0.9993 - precision: 0.8791 - recall: 0.6639 - auc: 0.9373 - val_loss: 0.0038 - val_tp: 84.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 19.0000 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8155 - val_auc: 0.9414
# Epoch 98/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0051 - tp: 165.0000 - fp: 25.0000 - tn: 139288.0000 - fn: 76.0000 - accuracy: 0.9993 - precision: 0.8684 - recall: 0.6846 - auc: 0.9415 - val_loss: 0.0038 - val_tp: 86.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 17.0000 - val_accuracy: 0.9995 - val_precision: 0.8600 - val_recall: 0.8350 - val_auc: 0.9414
# Epoch 99/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0052 - tp: 161.0000 - fp: 24.0000 - tn: 139289.0000 - fn: 80.0000 - accuracy: 0.9993 - precision: 0.8703 - recall: 0.6680 - auc: 0.9374 - val_loss: 0.0038 - val_tp: 83.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 20.0000 - val_accuracy: 0.9994 - val_precision: 0.8557 - val_recall: 0.8058 - val_auc: 0.9366
# Epoch 100/100
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0052 - tp: 149.0000 - fp: 20.0000 - tn: 139293.0000 - fn: 92.0000 - accuracy: 0.9992 - precision: 0.8817 - recall: 0.6183 - auc: 0.9414 - val_loss: 0.0037 - val_tp: 78.0000 - val_fp: 14.0000 - val_tn: 59693.0000 - val_fn: 25.0000 - val_accuracy: 0.9993 - val_precision: 0.8478 - val_recall: 0.7573 - val_auc: 0.9317

# %% [markdown]
# #### Check some of the performance graphs

# %%
plt.figure(figsize=(12, 8))

loss_train = epochs_history.history['loss']
loss_val = epochs_history.history['val_loss']

epochs = range(1,101)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='Validation loss')
plt.title('Training Loss vs Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 8))

loss_train = epochs_history.history['accuracy']
loss_val = epochs_history.history['val_accuracy']

epochs = range(1,101)
plt.plot(epochs, loss_train, 'g', label='Training Accuracy')
plt.plot(epochs, loss_val, 'b', label='Validation Accuracy')
plt.title('Training Accuracy vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model Validation

# %%
# Let us run the predictions

target_predictions = model.predict(features_test)

# %%
# Let us visualize the Confusion Matrix and detail out some key metrices including classification report

from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score, balanced_accuracy_score

def plot_cm(labels, predictions, threshold=0.5):
    cm = confusion_matrix(labels, predictions > threshold)
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title("Confusion Matrix %0.2f" %threshold)
    plt.xlabel("Predicted Label")
    plt.ylabel("Actual Label")
    
    print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
    print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
    print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
    print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
    print('Total Fraudulent Transactions: ', np.sum(cm[1]))
    print("\n")
    print("F1-Score")
    print(f1_score(target_test, target_predictions > 0.5))
    print("\n")
    print("Accuracy Score")
    print(accuracy_score(target_test, target_predictions > threshold))
    print("\n")
    print("Balanced Accuracy Score")
    print(balanced_accuracy_score(target_test, target_predictions > threshold))
    print("\n")
    print("Classification Report")
    print(classification_report(target_test, target_predictions > 0.5))

# %%
# Now use the function to plot the confusion matrix

plot_cm (target_test, target_predictions)
# Out:
# Legitimate Transactions Detected (True Negatives):  85281
# Legitimate Transactions Incorrectly Detected (False Positives):  14
# Fraudulent Transactions Missed (False Negatives):  39
# Fraudulent Transactions Detected (True Positives):  109
# Total Fraudulent Transactions:  148
#
#
# F1-Score
# 0.8044280442804429
#
#
# Accuracy Score
# 0.9993797034280163
#
#
# Balanced Accuracy Score
# 0.8681611751267065
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.89      0.74      0.80       148
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.87      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
