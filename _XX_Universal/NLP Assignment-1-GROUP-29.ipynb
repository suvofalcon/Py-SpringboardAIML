# %% [markdown]
# # NLP Assignment - 1
#
# ## Group - 29
#
# Description of Data: IMDB dataset having 50K movie reviews for natural language processing or Text analytics.
#
# This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. We provide a set of 25,000 highly polar movie reviews for training and 25,000 for testing. So, predict the number of positive and negative reviews using either classification or deep learning algorithms.
#
# Link to the dataset - https://www.kaggle.com/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews/download
#
# ### Approach
#
# We will use two different approaches to perform Sentiment Analysis
#
# <strong>Approach - 1 </strong><br>
# Using Machine Learning Algorithms like - Multinomial Naive Bayes and Linear Support Vector Machines
#
# <strong>Approach - 2 </strong><br>
# Using VADER Library from NLTK - Valence Aware Dictionary for Sentiment Reasoning

# %% [markdown]
# ## Library imports

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import spacy
sp = spacy.load('en_core_web_trf')
import spacy
from spacy import displacy
from wordcloud import WordCloud

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Load the dataset and validate the data load

# %%
reviews = pd.read_csv('../../../LargeDatasets/IMDBDataset.csv')

# Check oon the few rows
reviews.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# #### Check on the distribution of the sentiment variable

# %%
sns.countplot(x='sentiment', data=reviews)
print(reviews['sentiment'].value_counts())
# Out:
# positive    25000
# negative    25000
# Name: sentiment, dtype: int64

# %% [markdown]
# We have a balanced distribution between positive and negative reviews in the dataset

# %%
# Check for any missing values
reviews.isna().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %% [markdown]
# There are no missing values in the data

# %% [markdown]
# #### Let us examine one positive and one negative review

# %%
# Let us go through a positive review
reviews[reviews['sentiment'] == 'positive']['review'].iloc[0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %%
# Let us go through a negative review
reviews[reviews['sentiment'] == 'negative']['review'].iloc[0]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %% [markdown]
# ## Data Preparation
# ## Text Analytics and Text Cleanup

# %% [markdown]
# #### Remove Punctuations and some html chacracters using regular expressions

# %%
# Html characters and some symbols removal
reviews['review'] = reviews['review'].apply(lambda s : re.sub(r'<br />', '', s))

# Removing punctuations using Regex
reviews['review'] = reviews['review'].apply(lambda s : re.sub(r'[^\w\s]','', s))

# %% [markdown]
# #### Convert every review text words to lower case

# %%
# Conversion to Lower case

reviews['review'] = reviews['review'].str.lower()

# %%
# verify the reviews column now

reviews['review'].head()
# Out:
# 0    one of the other reviewers has mentioned that ...
# 1    a wonderful little production the filming tech...
# 2    i thought this was a wonderful way to spend ti...
# 3    basically theres a family where a little boy j...
# 4    petter matteis love in the time of money is a ...
# Name: review, dtype: object

# %% [markdown]
# #### Display POS Tagging for the first 4 reviews

# %%
# Display
for reviewText in reviews['review'][:4]:
    print("\n")
    print(f"Review Text - {reviewText}")
    reviewText = sp(reviewText)
    for ent in reviewText:
        print("------------------------------------------------------------------------")
        print(f'{ent.text:{10}} {ent.pos_:{8}} {ent.tag_:{8}} {spacy.explain(ent.tag_)}')
        #print(ent, ent.pos_)
# Out:
# Review Text - one of the other reviewers has mentioned that after watching just 1 oz episode youll be hooked they are right as this is exactly what happened with methe first thing that struck me about oz was its brutality and unflinching scenes of violence which set in right from the word go trust me this is not a show for the faint hearted or timid this show pulls no punches with regards to drugs sex or violence its is hardcore in the classic use of the wordit is called oz as that is the nickname given to the oswald maximum security state penitentary it focuses mainly on emerald city an experimental section of the prison where all the cells have glass fronts and face inwards so privacy is not high on the agenda em city is home to manyaryans muslims gangstas latinos christians italians irish and moreso scuffles death stares dodgy dealings and shady agreements are never far awayi would say the main appeal of the show is due to the fact that it goes where other shows wouldnt dare forget pretty pictures painted for mainstream audiences forget charm forget romanceoz doesnt mess around the first episode i ever saw struck me as so nasty it was surreal i couldnt say i was ready for it but as i watched more i developed a taste for oz and got accustomed to the high levels of graphic violence not just violence but injustice crooked guards wholl be sold out for a nickel inmates wholl kill on order and get away with it well mannered middle class inmates being turned into prison bitches due to their lack of street skills or prison experience watching oz you may become comfortable with what is uncomfortable viewingthats if you can get in touch with your darker side
# ------------------------------------------------------------------------
# one        NUM      CD       cardinal number
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# other      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# reviewers  NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# has        AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# mentioned  VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# that       SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# after      ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# watching   VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
# just       ADV      RB       adverb
# ------------------------------------------------------------------------
# 1          NUM      CD       cardinal number
# ------------------------------------------------------------------------
# oz         NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# episode    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# you        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# ll         AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# be         VERB     VB       verb, base form
# ------------------------------------------------------------------------
# hooked     ADJ      JJ       adjective
# ------------------------------------------------------------------------
# they       PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# are        AUX      VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# right      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# as         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# this       DET      DT       determiner
# ------------------------------------------------------------------------
# is         VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# exactly    ADV      RB       adverb
# ------------------------------------------------------------------------
# what       PRON     WP       wh-pronoun, personal
# ------------------------------------------------------------------------
# happened   VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# methe      X        XX       unknown
# ------------------------------------------------------------------------
# first      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# thing      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# that       DET      WDT      wh-determiner
# ------------------------------------------------------------------------
# struck     VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# me         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# about      ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# oz         PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# was        AUX      VBD      verb, past tense
# ------------------------------------------------------------------------
# its        PRON     PRP$     pronoun, possessive
# ------------------------------------------------------------------------
# brutality  NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# unflinching ADJ      JJ       adjective
# ------------------------------------------------------------------------
# scenes     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# violence   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# which      DET      WDT      wh-determiner
# ------------------------------------------------------------------------
# set        VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# in         ADP      RP       adverb, particle
# ------------------------------------------------------------------------
# right      ADV      RB       adverb
# ------------------------------------------------------------------------
# from       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# word       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# go         VERB     VB       verb, base form
# ------------------------------------------------------------------------
# trust      VERB     VB       verb, base form
# ------------------------------------------------------------------------
# me         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# this       DET      DT       determiner
# ------------------------------------------------------------------------
# is         VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# not        PART     RB       adverb
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# show       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# faint      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# hearted    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# or         CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# timid      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# this       DET      DT       determiner
# ------------------------------------------------------------------------
# show       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# pulls      VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# no         DET      DT       determiner
# ------------------------------------------------------------------------
# punches    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# regards    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# drugs      NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# sex        NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# or         CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# violence   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# its        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# is         VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# hardcore   ADJ      JJ       adjective
# ------------------------------------------------------------------------
# in         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# classic    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# use        NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# wordit     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# called     VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# oz         PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# as         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# that       DET      DT       determiner
# ------------------------------------------------------------------------
# is         VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# nickname   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# given      VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# oswald     PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# maximum    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# security   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# state      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# penitentary NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# it         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# focuses    VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# mainly     ADV      RB       adverb
# ------------------------------------------------------------------------
# on         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# emerald    PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# city       PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# an         DET      DT       determiner
# ------------------------------------------------------------------------
# experimental ADJ      JJ       adjective
# ------------------------------------------------------------------------
# section    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# prison     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# where      ADV      WRB      wh-adverb
# ------------------------------------------------------------------------
# all        DET      PDT      predeterminer
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# cells      NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# have       VERB     VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# glass      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# fronts     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# face       VERB     VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# inwards    ADV      RB       adverb
# ------------------------------------------------------------------------
# so         SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# privacy    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# not        PART     RB       adverb
# ------------------------------------------------------------------------
# high       ADJ      JJ       adjective
# ------------------------------------------------------------------------
# on         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# agenda     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# em         PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# city       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# home       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# manyaryans NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# muslims    PROPN    NNPS     noun, proper plural
# ------------------------------------------------------------------------
# gangstas   PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# latinos    PROPN    NNPS     noun, proper plural
# ------------------------------------------------------------------------
# christians PROPN    NNPS     noun, proper plural
# ------------------------------------------------------------------------
# italians   PROPN    NNPS     noun, proper plural
# ------------------------------------------------------------------------
# irish      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# moreso     PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# scuffles   NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# death      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# stares     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# dodgy      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# dealings   NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# shady      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# agreements NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# are        AUX      VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# never      ADV      RB       adverb
# ------------------------------------------------------------------------
# far        ADV      RB       adverb
# ------------------------------------------------------------------------
# awayi      PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# would      AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# say        VERB     VB       verb, base form
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# main       ADJ      JJ       adjective
# ------------------------------------------------------------------------
# appeal     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# show       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# due        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# fact       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# that       SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# it         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# goes       VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# where      ADV      WRB      wh-adverb
# ------------------------------------------------------------------------
# other      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# shows      NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# would      AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# nt         PART     RB       adverb
# ------------------------------------------------------------------------
# dare       VERB     VB       verb, base form
# ------------------------------------------------------------------------
# forget     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# pretty     ADJ      JJ       adjective
# ------------------------------------------------------------------------
# pictures   NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# painted    VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# mainstream ADJ      JJ       adjective
# ------------------------------------------------------------------------
# audiences  NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# forget     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# charm      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# forget     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# romanceoz  PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# does       AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# nt         PART     RB       adverb
# ------------------------------------------------------------------------
# mess       VERB     VB       verb, base form
# ------------------------------------------------------------------------
# around     ADP      RP       adverb, particle
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# first      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# episode    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# ever       ADV      RB       adverb
# ------------------------------------------------------------------------
# saw        VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# struck     VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# me         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# as         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# so         ADV      RB       adverb
# ------------------------------------------------------------------------
# nasty      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# it         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# was        AUX      VBD      verb, past tense
# ------------------------------------------------------------------------
# surreal    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# could      AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# nt         PART     RB       adverb
# ------------------------------------------------------------------------
# say        VERB     VB       verb, base form
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# was        AUX      VBD      verb, past tense
# ------------------------------------------------------------------------
# ready      ADJ      JJ       adjective
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# it         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# but        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# as         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# watched    VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# more       ADJ      JJR      adjective, comparative
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# developed  VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# taste      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# oz         PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# got        VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# accustomed ADJ      JJ       adjective
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# high       ADJ      JJ       adjective
# ------------------------------------------------------------------------
# levels     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# graphic    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# violence   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# not        PART     RB       adverb
# ------------------------------------------------------------------------
# just       ADV      RB       adverb
# ------------------------------------------------------------------------
# violence   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# but        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# injustice  NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# crooked    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# guards     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# who        PRON     WP       wh-pronoun, personal
# ------------------------------------------------------------------------
# ll         AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# be         AUX      VB       verb, base form
# ------------------------------------------------------------------------
# sold       VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# out        ADP      RP       adverb, particle
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# nickel     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# inmates    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# who        PRON     WP       wh-pronoun, personal
# ------------------------------------------------------------------------
# ll         AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# kill       VERB     VB       verb, base form
# ------------------------------------------------------------------------
# on         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# order      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# get        VERB     VB       verb, base form
# ------------------------------------------------------------------------
# away       ADP      RP       adverb, particle
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# it         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# well       ADV      RB       adverb
# ------------------------------------------------------------------------
# mannered   ADJ      JJ       adjective
# ------------------------------------------------------------------------
# middle     ADJ      JJ       adjective
# ------------------------------------------------------------------------
# class      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# inmates    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# being      AUX      VBN      verb, past participle
# ------------------------------------------------------------------------
# turned     VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# into       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# prison     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# bitches    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# due        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# their      PRON     PRP$     pronoun, possessive
# ------------------------------------------------------------------------
# lack       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# street     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# skills     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# or         CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# prison     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# experience NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# watching   VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
# oz         PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# you        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# may        AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# become     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# comfortable ADJ      JJ       adjective
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# what       PRON     WP       wh-pronoun, personal
# ------------------------------------------------------------------------
# is         VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# uncomfortable ADJ      JJ       adjective
# ------------------------------------------------------------------------
# viewingthats X        XX       unknown
# ------------------------------------------------------------------------
# if         SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# you        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# can        AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# get        VERB     VB       verb, base form
# ------------------------------------------------------------------------
# in         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# touch      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# your       PRON     PRP$     pronoun, possessive
# ------------------------------------------------------------------------
# darker     ADJ      JJR      adjective, comparative
# ------------------------------------------------------------------------
# side       NOUN     NN       noun, singular or mass
#
#
# Review Text - a wonderful little production the filming technique is very unassuming very oldtimebbc fashion and gives a comforting and sometimes discomforting sense of realism to the entire piece the actors are extremely well chosen michael sheen not only has got all the polari but he has all the voices down pat too you can truly see the seamless editing guided by the references to williams diary entries not only is it well worth the watching but it is a terrificly written and performed piece a masterful production about one of the great masters of comedy and his life the realism really comes home with the little things the fantasy of the guard which rather than use the traditional dream techniques remains solid then disappears it plays on our knowledge and our senses particularly with the scenes concerning orton and halliwell and the sets particularly of their flat with halliwells murals decorating every surface are terribly well done
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# wonderful  ADJ      JJ       adjective
# ------------------------------------------------------------------------
# little     ADJ      JJ       adjective
# ------------------------------------------------------------------------
# production NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# filming    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# technique  NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# very       ADV      RB       adverb
# ------------------------------------------------------------------------
# unassuming ADJ      JJ       adjective
# ------------------------------------------------------------------------
# very       ADV      RB       adverb
# ------------------------------------------------------------------------
# oldtimebbc ADJ      JJ       adjective
# ------------------------------------------------------------------------
# fashion    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# gives      VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# comforting ADJ      JJ       adjective
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# sometimes  ADV      RB       adverb
# ------------------------------------------------------------------------
# discomforting ADJ      JJ       adjective
# ------------------------------------------------------------------------
# sense      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# realism    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# to         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# entire     ADJ      JJ       adjective
# ------------------------------------------------------------------------
# piece      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# actors     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# are        AUX      VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# extremely  ADV      RB       adverb
# ------------------------------------------------------------------------
# well       ADV      RB       adverb
# ------------------------------------------------------------------------
# chosen     VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# michael    PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# sheen      PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# not        PART     RB       adverb
# ------------------------------------------------------------------------
# only       ADV      RB       adverb
# ------------------------------------------------------------------------
# has        AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# got        VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# all        DET      PDT      predeterminer
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# polari     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# but        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# he         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# has        VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# all        DET      PDT      predeterminer
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# voices     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# down       ADV      RB       adverb
# ------------------------------------------------------------------------
# pat        ADJ      JJ       adjective
# ------------------------------------------------------------------------
# too        ADV      RB       adverb
# ------------------------------------------------------------------------
# you        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# can        AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# truly      ADV      RB       adverb
# ------------------------------------------------------------------------
# see        VERB     VB       verb, base form
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# seamless   ADJ      JJ       adjective
# ------------------------------------------------------------------------
# editing    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# guided     VERB     VBN      verb, past participle
# ------------------------------------------------------------------------
# by         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# references NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# ...
# where      ADV      WRB      wh-adverb
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# little     ADJ      JJ       adjective
# ------------------------------------------------------------------------
# boy        NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# jake       PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# thinks     VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# there      VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# s          VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# zombie     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# in         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# his        PRON     PRP$     pronoun, possessive
# ------------------------------------------------------------------------
# closet     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
#            SPACE    _SP      None
# ------------------------------------------------------------------------
# his        PRON     PRP$     pronoun, possessive
# ------------------------------------------------------------------------
# parents    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# are        AUX      VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# fighting   VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
# all        DET      PDT      predeterminer
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# timethis   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# movie      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# slower     ADJ      JJR      adjective, comparative
# ------------------------------------------------------------------------
# than       SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# soap       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# opera      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# suddenly   ADV      RB       adverb
# ------------------------------------------------------------------------
# jake       PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# decides    VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# to         PART     TO       infinitival "to"
# ------------------------------------------------------------------------
# become     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# rambo      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# kill       VERB     VB       verb, base form
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# zombieok   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# first      ADV      RB       adverb
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# all        DET      DT       determiner
# ------------------------------------------------------------------------
# when       ADV      WRB      wh-adverb
# ------------------------------------------------------------------------
# you        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# re         AUX      VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# going      VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
# to         PART     TO       infinitival "to"
# ------------------------------------------------------------------------
# make       VERB     VB       verb, base form
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# film       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# you        PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# must       AUX      MD       verb, modal auxiliary
# ------------------------------------------------------------------------
# decide     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# if         SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# its        VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# thriller   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# or         CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# drama      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# as         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# drama      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# movie      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# is         AUX      VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# watchable  ADJ      JJ       adjective
# ------------------------------------------------------------------------
# parents    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# are        AUX      VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# divorcing  VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
#            SPACE    _SP      None
# ------------------------------------------------------------------------
# arguing    VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
# like       INTJ     UH       interjection
# ------------------------------------------------------------------------
# in         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# real       ADJ      JJ       adjective
# ------------------------------------------------------------------------
# life       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# then       ADV      RB       adverb
# ------------------------------------------------------------------------
# we         PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# have       VERB     VBP      verb, non-3rd person singular present
# ------------------------------------------------------------------------
# jake       PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# his        PRON     PRP$     pronoun, possessive
# ------------------------------------------------------------------------
# closet     NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# which      DET      WDT      wh-determiner
# ------------------------------------------------------------------------
# totally    ADV      RB       adverb
# ------------------------------------------------------------------------
# ruins      VERB     VBZ      verb, 3rd person singular present
# ------------------------------------------------------------------------
# all        DET      PDT      predeterminer
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# film       NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# expected   VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# to         PART     TO       infinitival "to"
# ------------------------------------------------------------------------
# see        VERB     VB       verb, base form
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# boogeyman  NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# similar    ADJ      JJ       adjective
# ------------------------------------------------------------------------
# movie      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# and        CCONJ    CC       conjunction, coordinating
# ------------------------------------------------------------------------
# instead    ADV      RB       adverb
# ------------------------------------------------------------------------
# i          PRON     PRP      pronoun, personal
# ------------------------------------------------------------------------
# watched    VERB     VBD      verb, past tense
# ------------------------------------------------------------------------
# a          DET      DT       determiner
# ------------------------------------------------------------------------
# drama      NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# some       DET      DT       determiner
# ------------------------------------------------------------------------
# meaningless ADJ      JJ       adjective
# ------------------------------------------------------------------------
# thriller   NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# spots3     NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# out        SCONJ    IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# of         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# 10         NUM      CD       cardinal number
# ------------------------------------------------------------------------
# just       ADV      RB       adverb
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# well       ADV      RB       adverb
# ------------------------------------------------------------------------
# playing    VERB     VBG      verb, gerund or present participle
# ------------------------------------------------------------------------
# parents    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
#            SPACE    _SP      None
# ------------------------------------------------------------------------
# descent    NOUN     NN       noun, singular or mass
# ------------------------------------------------------------------------
# dialogs    NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# as         ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# for        ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# the        DET      DT       determiner
# ------------------------------------------------------------------------
# shots      NOUN     NNS      noun, plural
# ------------------------------------------------------------------------
# with       ADP      IN       conjunction, subordinating or preposition
# ------------------------------------------------------------------------
# jake       PROPN    NNP      noun, proper singular
# ------------------------------------------------------------------------
# just       ADV      RB       adverb
# ------------------------------------------------------------------------
# ignore     VERB     VB       verb, base form
# ------------------------------------------------------------------------
# them       PRON     PRP      pronoun, personal

# %%
# We will remove the stopwords for every review in the column 
reviews['review'] = reviews['review'].apply(lambda x : ' '.join([word for word in x.split() if not word in sp.Defaults.stop_words]))

# %%
reviews['review'][:4]
# Out:
# 0    reviewers mentioned watching 1 oz episode youl...
# 1    wonderful little production filming technique ...
# 2    thought wonderful way spend time hot summer we...
# 3    basically theres family little boy jake thinks...
# Name: review, dtype: object

# %% [markdown]
# #### Build Word Clouds for both positive and negative reviews

# %%
# We will display the word cloud for all positive reviews

text = " ".join(reviewtext for reviewtext in reviews[reviews['sentiment'] == 'positive']['review'])
word_cloud = WordCloud(collocations=False, background_color='white').generate(text)

# Display the generated word cloud
plt.figure(figsize=(12, 8))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# We will display the word cloud for all negative reviews

text = " ".join(reviewtext for reviewtext in reviews[reviews['sentiment'] == 'negative']['review'])
word_cloud = WordCloud(collocations=False, background_color='white').generate(text)

# Display the generated word cloud
plt.figure(figsize=(12, 8))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Modelling Preparation
#
# ### Label Encoding the target attribute 'sentiment'
# ### Peform the Train-Test Split

# %%
# Label encoding the target attribute 'sentiment'
encoder = LabelEncoder()
reviews['sentiment'] = encoder.fit_transform(reviews['sentiment'])

# %%
# Perform the train-test split

features = reviews['review']
target = reviews['sentiment']

# Perform the split
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.10, random_state=101)

# %% [markdown]
# ## Model Approach 1 - Sentiment Analysis using Multinomial NB, Support Vector Classifier

# %% [markdown]
# ### We will develop a selection of pipeline, each with a different model
#
# In each pipeline, TfidfVectorization will happen followed by the application of the specific modelling technique

# %%
# Build the pipeline

# Multinomial Naive Bayes:
text_clf_nb = Pipeline([('tfidf', TfidfVectorizer()), 
                        ('clf', MultinomialNB())])

# Linear SVC:
text_clf_lsvc = Pipeline([('tfidf', TfidfVectorizer()), 
                          ('clf', LinearSVC())])

# %%
# Feed the training data through the pipelines

# Pipeline - multinomial Naive Bayes
text_clf_nb.fit(features_train, target_train)

# Pipeline - Linear Support Vector Classifier
text_clf_lsvc.fit(features_train, target_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
# Run the predictions for both the text classifiers

predictions_nb = text_clf_nb.predict(features_test)
predictions_lsvc = text_clf_lsvc.predict(features_test)

# %% [markdown]
# #### Model Performance - Multinomial Naive Bayes

# %%
print("Accuracy Score")
print(accuracy_score(target_test, predictions_nb))
print("\n")
print("Classification Report")
print(classification_report(target_test, predictions_nb))
print("\n")
print("Confusion Matrix")
print(confusion_matrix(target_test, predictions_nb))
print("\n")
print("F1 Score")
print(f1_score(target_test, predictions_nb))
# Out:
# Accuracy Score
# 0.8728
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87      2386
#            1       0.90      0.85      0.87      2614
#
#     accuracy                           0.87      5000
#    macro avg       0.87      0.87      0.87      5000
# weighted avg       0.87      0.87      0.87      5000
#
#
#
# Confusion Matrix
# [[2139  247]
#  [ 389 2225]]
#
#
# F1 Score
# 0.8749508454581203

# %% [markdown]
# #### Model Performance - Linear SVC

# %%
print("Accuracy Score")
print(accuracy_score(target_test, predictions_lsvc))
print("\n")
print("Classification Report")
print(classification_report(target_test, predictions_lsvc))
print("\n")
print("Confusion Matrix")
print(confusion_matrix(target_test, predictions_lsvc))
print("\n")
print("F1 Score")
print(f1_score(target_test, predictions_lsvc))
# Out:
# Accuracy Score
# 0.9018
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      2386
#            1       0.90      0.91      0.91      2614
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
#
#
#
# Confusion Matrix
# [[2135  251]
#  [ 240 2374]]
#
#
# F1 Score
# 0.9062798243939684

# %% [markdown]
# ## Model Approach 2 - Sentiment Analysis using VADER from NLTK (Valence Aware Dictionary for Sentiment Reasoning)

# %%
sid = SentimentIntensityAnalyzer()

# %% [markdown]
# #### Use this intensity analyzer to append a compound score to the dataset

# %%
reviews['scores'] = reviews['review'].apply(lambda review: sid.polarity_scores(review))
reviews['compound'] = reviews['scores'].apply(lambda score_dict: score_dict['compound'])
reviews['comp_score'] = reviews['compound'].apply(lambda x: 1 if x >= 0 else 0)
reviews.head()
# Out:
#                                               review  sentiment  \
# 0  reviewers mentioned watching 1 oz episode youl...          1
# 1  wonderful little production filming technique ...          1
# 2  thought wonderful way spend time hot summer we...          1
# 3  basically theres family little boy jake thinks...          0
# 4  petter matteis love time money visually stunni...          1
#
#                                               scores  compound  comp_score
# 0  {'neg': 0.331, 'neu': 0.567, 'pos': 0.102, 'co...   -0.9938           0
# 1  {'neg': 0.091, 'neu': 0.66, 'pos': 0.249, 'com...    0.9153           1
# 2  {'neg': 0.145, 'neu': 0.504, 'pos': 0.352, 'co...    0.9666           1
# 3  {'neg': 0.244, 'neu': 0.663, 'pos': 0.092, 'co...   -0.9286           0
# 4  {'neg': 0.034, 'neu': 0.682, 'pos': 0.284, 'co...    0.9871           1

# %%
print("Accuracy Score")
print(accuracy_score(reviews['sentiment'], reviews['comp_score']))
print("\n")
print(classification_report(reviews['sentiment'], reviews['comp_score']))
print("\n")
print(confusion_matrix(reviews['sentiment'], reviews['comp_score']))
# Out:
# Accuracy Score
# 0.67348
#
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.49      0.60     25000
#            1       0.63      0.86      0.72     25000
#
#     accuracy                           0.67     50000
#    macro avg       0.70      0.67      0.66     50000
# weighted avg       0.70      0.67      0.66     50000
#
#
#
# [[12290 12710]
#  [ 3616 21384]]

# %% [markdown]
# ## Dependency Parser Tree for the sentence below
#
# **“The Starks have now effectively lost all their power, and the surviving Stark children are scattered around the continent, either prisoners or in hiding."**

# %%
doc = sp(u"The Starks have now effectively lost all their power, and the surviving Stark children are scattered around the continent, either prisoners or in hiding.")

# Render the dependency parse immediately inside Jupyter:
displacy.render(doc, style='dep', jupyter=True, options={'distance': 85})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="672947c0a0d0420fa98b835e0e96c438-0" class="displacy" width="2090" height="392.0" direction="ltr" style="max-width: none; height: 392.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="135">Starks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="220">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="220">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="305">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="390">effectively</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="390">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="475">lost</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="475">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="560">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="560">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="645">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="645">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">power,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="815">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="815">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="985">surviving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="985">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1070">Stark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1070">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1155">children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1155">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1240">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1240">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1325">scattered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1495">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1495">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">continent,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1665">either</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1665">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">prisoners</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1835">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1835">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="302.0">
#     <tspan class="displacy-word" fill="currentColor" x="2005">hiding.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2005">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-672947c0a0d0420fa98b835e0e96c438-0-0" stroke-width="2px" d="M70,257.0 C70,214.5 110.0,214.5 110.0,257.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-672947c0a0d0420fa98b835e0e96c438-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,259.0 L62,247.0 78,247.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-672947c0a0d0420fa98b835e0e96c438-0-1" stroke-width="2px" d="M155,257.0 C155,87.0 465.0,87.0 465.0,257.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-672947c0a0d0420fa98b835e0e96c438-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M155,259.0 L147,247.0 163,247.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-672947c0a0d0420fa98b835e0e96c438-0-2" stroke-width="2px" d="M240,257.0 C240,129.5 460.0,129.5 460.0,257.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-672947c0a0d0420fa98b835e0e96c438-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M240,259.0 L232,247.0 248,247.0" fill=
