# %% [markdown]
# # Deep Learning Assignment - 01 , Problem - 02, Group - 029
# # Fake and Real News
#
# Model to determine if an article is fake news or not ?

# %% [markdown]
# ## Library Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import warnings
warnings.simplefilter("ignore")

import tensorflow as tf
import tensorflow_hub as hub

from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Validate GPU Availability

# %%
# Note this code is only valid if GPU is being used for training

# Before we run the parameter tuning, we will work with little gpu memory allocation
# we will only use that much of memory of gpu as it is needed - allow the growth of gpu memory as it is needed
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
else:
    print("No GPU Available, switching to CPU Version")
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Load the dataset and validate the data load
#
# We will load the individual dataset, create a target attribute which will indicate 1 if the news is fake. Combine both the dataframes and create the combined dataframe for modelling

# %%
# Load the fake and real news datasets
fake_news = pd.read_csv("dataset/Fake.csv")
fake_news["fake"] = 1

# Load the real news 
real_news = pd.read_csv("dataset/True.csv")
real_news["fake"] = 0

# We will join the two dataframes and create the combined one for modelling

news = pd.concat([fake_news, real_news])
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  fake
# 0  December 31, 2017     1
# 1  December 31, 2017     1
# 2  December 30, 2017     1
# 3  December 29, 2017     1
# 4  December 25, 2017     1

# %%
# Check for any null values
news.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# fake       0
# dtype: int64

# %%
# Check the data structure
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   fake     44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Exploratory Data Analysis - Data Visualizations

# %% [markdown]
# #### Explore the target variable

# %%
# Explore the target variable
sns.countplot(x='fake', data=news)
print("Distributions...")
print(news['fake'].value_counts())
# Out:
# Distributions...
# 1    23481
# 0    21417
# Name: fake, dtype: int64

# %% [markdown]
# We see good distibution of data in both the classes

# %% [markdown]
# #### Explore at least 2 texts from each class

# %%
# Explore 2 texts for the fake dataset
news[news['fake'] == 1]['text'].head(2)
# Out:
# 0    Donald Trump just couldn t wish all Americans ...
# 1    House Intelligence Committee Chairman Devin Nu...
# Name: text, dtype: object

# %%
# Expore 2 textx for the real news
news[news['fake'] == 0]['text'].head(2)
# Out:
# 0    WASHINGTON (Reuters) - The head of a conservat...
# 1    WASHINGTON (Reuters) - Transgender people will...
# Name: text, dtype: object

# %% [markdown]
# #### Explore the Subject column

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='subject', data=news, hue='fake')
# Out:
# <AxesSubplot:xlabel='subject', ylabel='count'>

# %% [markdown]
# This clearly shows that any news which is not of "policticsNews or worldnews" is a fake news. This perfectly seggregates the data into two classes and hence is not a choice for classification modelling. We would drop this attribute before we begin modelling

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### We will create a new columns called Month and Year from Date and analyse whether fake or real news has some correlation with Month or Year in the timeline

# %%
news['date'] = pd.to_datetime(news['date'], errors='coerce')
news['Year'] = news['date'].dt.year
news['Month'] = news['date'].dt.month

news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject       date  fake  \
# 0  Donald Trump just couldn t wish all Americans ...    News 2017-12-31     1
# 1  House Intelligence Committee Chairman Devin Nu...    News 2017-12-31     1
# 2  On Friday, it was revealed that former Milwauk...    News 2017-12-30     1
# 3  On Christmas day, Donald Trump announced that ...    News 2017-12-29     1
# 4  Pope Francis used his annual Christmas Day mes...    News 2017-12-25     1
#
#      Year  Month
# 0  2017.0   12.0
# 1  2017.0   12.0
# 2  2017.0   12.0
# 3  2017.0   12.0
# 4  2017.0   12.0

# %%
# Check the impact of Year on the target variable
sns.countplot(x='Year', data=news, hue='fake')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# All news in the year 2015 in the dataset is a fake news. So this attribute has a level which perfectly distributes the target variable.

# %%
# Check the impact of Month on the target variable
sns.countplot(x='Month', data=news, hue='fake')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %% [markdown]
# This shows an interesting pattern - The number of fake news is higher till month 8, post which the number of real news increases drastically. Which essentially means if the month is <= 8, the probability of fake news is higher.

# %% [markdown]
# #### We will combine the title and text column

# %%
news['text'] = news['title'] + news['text']
news.drop(labels=['title'], axis=1, inplace=True)

news.head()
# Out:
#                                                 text subject       date  fake  \
# 0   Donald Trump Sends Out Embarrassing New Year’...    News 2017-12-31     1
# 1   Drunk Bragging Trump Staffer Started Russian ...    News 2017-12-31     1
# 2   Sheriff David Clarke Becomes An Internet Joke...    News 2017-12-30     1
# 3   Trump Is So Obsessed He Even Has Obama’s Name...    News 2017-12-29     1
# 4   Pope Francis Just Called Out Donald Trump Dur...    News 2017-12-25     1
#
#      Year  Month
# 0  2017.0   12.0
# 1  2017.0   12.0
# 2  2017.0   12.0
# 3  2017.0   12.0
# 4  2017.0   12.0

# %% [markdown]
# ## Preparing the final data
#
# We will remove the subject attribute - Since it perfectly distributes the target variable
# We will remove the Year attribute - This also has a clear division for the target variable
# We will remove the Month Attribute - This also has a very clear approach of demarcating the target variable
#
# For now we will just go ahead with the "text attribute"

# %%
news.drop(labels=['subject', 'date', 'Year', 'Month'], axis=1, inplace=True)
news.head()
# Out:
#                                                 text  fake
# 0   Donald Trump Sends Out Embarrassing New Year’...     1
# 1   Drunk Bragging Trump Staffer Started Russian ...     1
# 2   Sheriff David Clarke Becomes An Internet Joke...     1
# 3   Trump Is So Obsessed He Even Has Obama’s Name...     1
# 4   Pope Francis Just Called Out Donald Trump Dur...     1

# %% [markdown]
# ## Train-Test Split

# %%
# We will shuffle the dataframe and extract the feature and label

news = news.sample(frac=1)
feature_text = news['text']
target = news['fake']

# %%
# Perform the split
features_train, features_test, target_train, target_test = train_test_split(feature_text, target, test_size=0.3, 
                                                                            random_state=101)

# We will further split the training set into validatoion to evaluate the Neural Network training
features_train, features_val, target_train, target_val = train_test_split(features_train, target_train, test_size=0.3, 
                                                                            random_state=101)

print("Training Features shape: ", features_train.shape)
print("Training Target shape: ", target_train.shape)

print("Validation Features shape: ", features_val.shape)
print("Validation Target shape: ", target_val.shape)

print("Test Features shape: ", features_test.shape)
print("Training Target shape: ", target_test.shape)
# Out:
# Training Features shape:  (21999,)
# Training Target shape:  (21999,)
# Validation Features shape:  (9429,)
# Validation Target shape:  (9429,)
# Test Features shape:  (13470,)
# Training Target shape:  (13470,)

# %%
# First 10 training samples
features_train[: 10]
# Out:
# 489      Senate Republicans shove tax bill ahead as Dem...
# 21067    FLINT RESIDENTS TOLD TO PAY BILLS FOR POISON W...
# 2423     Trump to sign Russia sanctions bill: White Hou...
# 9347     LOL! DEMOCRAT CHEERLEADER Cokie Roberts Delive...
# 9020     Medicare program spending within target rate: ...
# 11610    Turkish President calls UAE minister impertine...
# 16114    GOP VETERAN AND DOUBLE AMPUTEE Scorches Democr...
# 9650     Former Republican presidential hopeful Graham:...
# 15852    FAMILY OF S.C. SHOOTING VICTIM HAS A MESSAGE F...
# 1357      Trump And His ‘Street Fighters’ Prepare To Wa...
# Name: text, dtype: object

# %%
# First 10 training classes (target)
target_train[: 10]
# Out:
# 489      0
# 21067    1
# 2423     0
# 9347     1
# 9020     0
# 11610    0
# 16114    1
# 9650     0
# 15852    1
# 1357     1
# Name: fake, dtype: int64

# %% [markdown]
# ## Build and Train the Neural Network Model

# %% [markdown]
# #### Global Model Constants

# %%
# Define some global Model Constants

INPUT_SHAPE = []

OUTPUT_UNITS = 1
HIDDEN_UNITS_SINGLE = 16
HIDDEN_UNITS_DEEP = 8
ACTIVATION_HIDDEN = tf.keras.activations.relu
ACTIVATION_OUTPUT = tf.keras.activations.sigmoid
LEARNING_RATE = 1e-3
OPTIMIZER = tf.keras.optimizers.Adam(LEARNING_RATE)
LOSS_FUNCTION = tf.keras.losses.BinaryCrossentropy(from_logits=True)
L2_REGULARIZER = tf.keras.regularizers.L2(0.001)
DROPOUT_RATE = 0.2

EPOCHS = 10

# %% [markdown]
# #### Define the Model evaluation Metrics

# %%
# Define the Metrics - These are the metrics we will evaluate during training

METRICS = [tf.keras.metrics.TruePositives(name='tp'),
          tf.keras.metrics.FalsePositives(name='fp'),
          tf.keras.metrics.TrueNegatives(name='tn'),
          tf.keras.metrics.FalseNegatives(name='fn'), 
          tf.keras.metrics.BinaryAccuracy(name='accuracy'),
          tf.keras.metrics.Precision(name='precision'),
          tf.keras.metrics.Recall(name='recall'),
          tf.keras.metrics.AUC(name='auc')]

# %% [markdown]
# #### In order to perform text processing, we would be using a pre-trained embedding layer from tensorflow-hub
# We will create a Keras Layer that uses tensorflow hub model to embed sentences
#
# #### The first layer is a TensorFlow Hub layer. This layer uses a pre-trained Saved Model to map a sentence into its embedding vector. The model that we are using (google/nnlm-en-dim128/2) splits the sentence into tokens, embeds each token and then combines the embedding.

# %%
model_embeddings = "https://tfhub.dev/google/nnlm-en-dim128/2"
hub_layer = hub.KerasLayer(model_embeddings, input_shape=INPUT_SHAPE, dtype=tf.string, trainable=True)

# We will use it in the first two samples and check
hub_layer(features_train[:2])
# Out:
# <tf.Tensor: shape=(2, 128), dtype=float32, numpy=
# array([[ 2.33262968e+00,  4.64941651e-01,  3.37151960e-02,
#         -4.78797287e-01,  4.99797553e-01, -3.64353120e-01,
#         -1.92317758e-02, -3.68486391e-03,  2.26832852e-02,
#          5.24912953e-01,  1.08833827e-01, -2.98908293e-01,
#          2.84812180e-03,  9.17757154e-02, -5.81333756e-01,
#         -2.38915801e-01, -2.32952684e-01, -3.69742513e-01,
#         -2.65988648e-01,  2.42873168e+00, -4.68233705e-01,
#          7.97620654e-01, -1.83914319e-01,  5.22875845e-01,
#         -1.07327096e-01,  3.69328350e-01, -5.73887303e-02,
#         -3.88759263e-02, -3.54078934e-02, -3.07324171e-01,
#          1.96787626e-01, -4.39755991e-02,  2.46347025e-01,
#          2.05564231e-01,  2.86294103e-01, -1.90517325e-02,
#         -1.31426856e-01, -3.18047881e-01, -4.02904093e-01,
#          4.51421708e-01, -1.69376433e-01,  5.88673651e-01,
#         -7.58562982e-02,  2.48478174e-01,  3.23800594e-01,
#          5.50269604e-01, -9.90799367e-02,  1.37689672e-02,
#         -6.46310151e-02, -5.93201816e-01,  2.18512900e-02,
#          2.80406535e-01,  3.06638688e-01, -4.13245678e-01,
#         -5.80042720e-01, -3.63483392e-02, -2.07698494e-01,
#         -5.91171347e-02,  4.56163019e-01, -5.45697436e-02,
#         -8.80456045e-02,  1.04299076e-01, -4.10924196e-01,
#         -6.73175097e-01,  1.92559883e-01,  3.17799449e-01,
#          1.41029358e-01, -5.22720873e-01,  4.67857830e-02,
#         -5.07807910e-01,  2.49860913e-01, -5.52622795e-01,
#         -3.62680219e-02,  2.06178904e-01, -2.78553545e-01,
#          1.46257043e-01,  2.38044307e-01, -7.31136560e-01,
#         -5.17960370e-01, -5.43691754e-01,  3.99088621e-01,
#         -2.40517303e-01,  7.84831718e-02, -3.91540796e-01,
#          7.15912700e-01, -5.63698113e-01, -7.07977414e-01,
#          1.38930038e-01,  1.52844727e+00,  4.33289319e-01,
#         -4.53149617e-01,  4.45598692e-01,  2.25902319e-01,
#         -3.89507324e-01, -3.81841540e-01,  3.79952729e-01,
#          3.71902287e-01,  1.80529162e-01, -1.14883888e+00,
#          2.59613305e-01, -2.09501475e-01, -3.57176483e-01,
#         -3.18332911e-01, -6.49328753e-02,  4.25049588e-02,
#         -4.38255847e-01,  1.71137840e-01,  2.71306127e-01,
#         -2.47844011e-01,  2.96918722e-03, -9.19339299e-01,
#          1.08708359e-01,  1.67267755e-01, -4.61867601e-01,
#          1.90983653e-01,  4.84798223e-01,  1.21607043e-01,
#          4.81680185e-01, -1.41161025e-01, -3.78152765e-02,
#          5.76957725e-02, -3.36329073e-01,  1.67941079e-01,
#          1.93408817e-01,  5.06161191e-02, -2.58193761e-01,
#         -4.74205017e-02,  1.08778710e-02],
#        [ 2.50355911e+00,  3.33716601e-01,  1.03410974e-01,
#          2.90823430e-01,  1.36013076e-01, -2.61410922e-01,
#         -7.43722096e-02, -2.75791556e-01, -2.27736160e-01,
#          3.15585434e-01,  1.89949855e-01,  2.71255761e-01,
#         -3.99738729e-01, -2.56536096e-01, -3.23219657e-01,
#         -3.09703261e-01, -4.29754078e-01, -1.08768302e-03,
#         -4.44256186e-01,  2.16692638e+00, -7.10874274e-02,
#          1.72592342e-01, -2.20351797e-02, -5.49855903e-02,
#         -1.97313100e-01,  4.63031121e-02,  4.14605856e-01,
#         -1.97353050e-01, -4.56274271e-01, -8.35227743e-02,
#          2.45789126e-01,  5.51454164e-02,  2.38118455e-01,
#         -4.34232429e-02,  1.36679426e-01, -3.38423103e-02,
#         -3.28606427e-01, -5.19924045e-01, -5.58828376e-02,
#          2.71999359e-01,  8.65160376e-02, -1.98217049e-01,
#         -2.08648145e-02, -2.50504851e-01,  2.84681618e-01,
#          1.50096387e-01,  2.80528456e-01, -8.00257623e-02,
#         -3.22999433e-02, -6.92681223e-02, -7.95987695e-02,
#          2.80988216e-01,  3.96743238e-01, -7.07075186e-03,
#         -3.23310941e-01,  3.32187017e-04, -1.49396613e-01,
#          3.55767794e-02,  1.17589056e-01,  5.25717497e-01,
#         -2.86849588e-01,  2.93675661e-01, -1.45123631e-01,
#         -4.82572585e-01,  2.97027137e-02,  2.36023188e-01,
#          2.67291456e-01, -4.07592148e-01,  2.54623741e-01,
#         -2.53786117e-01, -1.83831796e-01,  1.51645079e-01,
#          1.79322481e-01, -9.76660922e-02,  7.43013024e-02,
#          9.71196070e-02, -5.52801304e-02, -2.58239180e-01,
#         -1.41303256e-01,  8.49782601e-02,  4.64044303e-01,
#          1.07977055e-01,  3.05623777e-04,  9.79133174e-02,
#          1.65265098e-01, -3.75789970e-01, -8.22760642e-01,
#          7.13987499e-02,  1.58326483e+00,  6.77034855e-01,
#         -4.83393550e-01,  3.61065388e-01, -2.51381725e-01,
#         -6.08646870e-01,  2.58935601e-01,  5.64178228e-01,
#          6.93807080e-02, -7.43193924e-02, -5.56116581e-01,
#          1.93994731e-01,  3.46857131e-01,  9.33869779e-02,
#         -2.54144613e-02,  4.47282970e-01,  8.79702643e-02,
#         -6.44787475e-02, -2.23294675e-01,  1.97656155e-01,
#         -3.41430366e-01,  4.91625676e-03, -1.15368235e+00,
#         -2.32222661e-01, -5.58052547e-02, -3.39687973e-01,
#          1.59150571e-01, -1.73829332e-01,  9.35000852e-02,
#          1.37031198e-01,  3.09383154e-01,  2.24760190e-01,
#          1.59156173e-01, -5.40831327e-01,  4.17095184e-01,
#          1.25707984e-01, -7.26992190e-02, -2.69879133e-01,
#         -1.79823682e-01,  6.22872300e-02]], dtype=float32)>

# %% [markdown]
# ### Building and Compiling the Model
#
# We will build two models
#
# **Simple Model** - Without any regularization and dropout and a single hidden layer<br>
# **Deep Neural Model** - With multiple hidden layers, L2 regularization and Dropouts <br><br>
#
# **Performace Graph Functions** - We will define functions for plotting performance graphs
# - Training Loss vs Validation Loss
# - Training Accuracy vs Validation Accuracy

# %%
# Defining a function which will build and compile the model

'''
This will build and compile a model with one hidden layer and 16 neurons
'''
def make_model(metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)
    model = tf.keras.Sequential()
    model.add(hub_layer)
    model.add(tf.keras.layers.Dense(units=HIDDEN_UNITS_SINGLE, activation=ACTIVATION_HIDDEN))
    model.add(tf.keras.layers.Dense(units=OUTPUT_UNITS, activation=ACTIVATION_OUTPUT))
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=metrics)
    return model

# %%
'''
This will build a deep neural network model with multiple hidden layers and implement 
L2 regularization
Dropout regularization
'''

def make_DNNModel(metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)
    model = tf.keras.Sequential()
    model.add(hub_layer)
    model.add(tf.keras.layers.Dense(units=HIDDEN_UNITS_DEEP, activation=ACTIVATION_HIDDEN, kernel_regularizer=L2_REGULARIZER))
    model.add(tf.keras.layers.Dropout(rate=DROPOUT_RATE))
    model.add(tf.keras.layers.Dense(units=HIDDEN_UNITS_DEEP, activation=ACTIVATION_HIDDEN, kernel_regularizer=L2_REGULARIZER))
    model.add(tf.keras.layers.Dense(units=OUTPUT_UNITS, activation=ACTIVATION_OUTPUT))
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=metrics)
    return model

# %%
# Defining a function to plot training loss vs validation loss

'''
This function will take a epoch model from training a neural network
Will plot training loss vs validation loss
'''

def plotTrainLossVsValLoss(epochs_history):
    plt.figure(figsize=(12, 8))
    loss_train = epochs_history.history['loss']
    loss_val = epochs_history.history['val_loss']

    plt.figure(figsize=(12, 8))

    loss_train = epochs_history.history['loss']
    loss_val = epochs_history.history['val_loss']

    epochs = range(1, (EPOCHS + 1))
    plt.plot(epochs, loss_train, 'g', label='Training loss')
    plt.plot(epochs, loss_val, 'b', label='Validation loss')
    plt.title('Training Loss vs Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Defining a function to plot training accuracy vs validation accuracy

'''
This function will take a epoch model from training a neural network
Will plot training accuracy vs validation accuracy
'''

def plotTrainAccuracyVsValAccuracy(epochs_history):
    plt.figure(figsize=(12, 8))

    loss_train = epochs_history.history['accuracy']
    loss_val = epochs_history.history['val_accuracy']

    epochs = range(1, (EPOCHS + 1))
    plt.plot(epochs, loss_train, 'g', label='Training Accuracy')
    plt.plot(epochs, loss_val, 'b', label='Validation Accuracy')
    plt.title('Training Accuracy vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Defining a function to plot the confusion matrix
# Let us visualize the Confusion Matrix and detail out some key metrices including classification report

'''
This function will plot the confusion matrix 
This will also display various performance metrices
'''
def plot_cm(labels, predictions, threshold=0.5):
    cm = confusion_matrix(labels, predictions > threshold)
    plt.figure(figsize=(5, 5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title("Confusion Matrix %0.2f" %threshold)
    plt.xlabel("Predicted Label")
    plt.ylabel("Actual Label")
    
    print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
    print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
    print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
    print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
    print('Total Fraudulent Transactions: ', np.sum(cm[1]))
    print("\n")
    print("F1-Score")
    print(f1_score(target_test, target_predictions > 0.5))
    print("\n")
    print("Accuracy Score")
    print(accuracy_score(target_test, target_predictions > threshold))
    print("\n")
    print("Classification Report")
    print(classification_report(target_test, target_predictions > 0.5))

# %% [markdown]
# #### Compile the Simple Model

# %%
# Lets build the model and see the mmodel summary

simplemodel = make_model()
simplemodel.summary()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x7f22485f8a30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x7f22485f8a30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x7f22485f8a30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 128)               124642688
# _________________________________________________________________
# dense (Dense)                (None, 16)                2064
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 124,644,769
# Trainable params: 124,644,769
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Training the model

# %%
# we will now train the model on training and validation data
# Now use the function to plot the confusion matrix

start = datetime.now()
epochs_history_simple = simplemodel.fit(features_train, target_train, epochs=EPOCHS,
                          validation_data=(features_val, target_val),
                          verbose=1)
end = datetime.now()
print(f"The training of simple model completed in time - {end - start}")
# Out:
# Epoch 1/10
# 688/688 [==============================] - 38s 52ms/step - loss: 0.1513 - tp: 5537.6720 - fp: 104.0769 - tn: 5211.8142 - fn: 186.3411 - accuracy: 0.9496 - precision: 0.9617 - recall: 0.9373 - auc: 0.9817 - val_loss: 0.0093 - val_tp: 4920.0000 - val_fp: 4.0000 - val_tn: 4479.0000 - val_fn: 26.0000 - val_accuracy: 0.9968 - val_precision: 0.9992 - val_recall: 0.9947 - val_auc: 1.0000
# Epoch 2/10
# 688/688 [==============================] - 36s 52ms/step - loss: 0.0032 - tp: 5771.5443 - fp: 1.8752 - tn: 5262.9216 - fn: 3.5631 - accuracy: 0.9994 - precision: 0.9996 - recall: 0.9992 - auc: 0.9999 - val_loss: 0.0051 - val_tp: 4940.0000 - val_fp: 8.0000 - val_tn: 4475.0000 - val_fn: 6.0000 - val_accuracy: 0.9985 - val_precision: 0.9984 - val_recall: 0.9988 - val_auc: 1.0000
# Epoch 3/10
# 688/688 [==============================] - 36s 53ms/step - loss: 2.5757e-04 - tp: 5766.0595 - fp: 0.0000e+00 - tn: 5273.8447 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0045 - val_tp: 4938.0000 - val_fp: 6.0000 - val_tn: 4477.0000 - val_fn: 8.0000 - val_accuracy: 0.9985 - val_precision: 0.9988 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 4/10
# 688/688 [==============================] - 37s 53ms/step - loss: 1.0175e-04 - tp: 5727.4964 - fp: 0.0000e+00 - tn: 5312.4078 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0044 - val_tp: 4938.0000 - val_fp: 6.0000 - val_tn: 4477.0000 - val_fn: 8.0000 - val_accuracy: 0.9985 - val_precision: 0.9988 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 5/10
# 688/688 [==============================] - 36s 53ms/step - loss: 5.6120e-05 - tp: 5771.1930 - fp: 0.0000e+00 - tn: 5268.7112 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 6/10
# 688/688 [==============================] - 36s 53ms/step - loss: 3.6021e-05 - tp: 5764.4383 - fp: 0.0000e+00 - tn: 5275.4659 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 7/10
# 688/688 [==============================] - 36s 53ms/step - loss: 1.9541e-05 - tp: 5745.5457 - fp: 0.0000e+00 - tn: 5294.3585 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 8/10
# 688/688 [==============================] - 36s 53ms/step - loss: 1.2925e-05 - tp: 5773.0435 - fp: 0.0000e+00 - tn: 5266.8607 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 0.9999
# Epoch 9/10
# 688/688 [==============================] - 36s 53ms/step - loss: 8.8421e-06 - tp: 5729.0871 - fp: 0.0000e+00 - tn: 5310.8171 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 0.9999
# Epoch 10/10
# 688/688 [==============================] - 37s 53ms/step - loss: 5.4601e-06 - tp: 5776.9492 - fp: 0.0000e+00 - tn: 5262.9550 - fn: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.0043 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 0.9999
# The training of simple model completed in time - 0:06:05.455830

# %% [markdown]
# #### Check Performance Graphs

# %%
# Plot training loss vs validation loss
plotTrainLossVsValLoss(epochs_history=epochs_history_simple)

# %%
# Plot Training accuracy vs Validation accuracy
plotTrainAccuracyVsValAccuracy(epochs_history=epochs_history_simple)

# %% [markdown]
# #### Model Validation for the Simple Model

# %%
# Let us run the predictions
target_predictions = simplemodel.predict(features_test)

# %%
# Now use the function to plot the confusion matrix
plot_cm (target_test, target_predictions)
# Out:
# Legitimate Transactions Detected (True Negatives):  6382
# Legitimate Transactions Incorrectly Detected (False Positives):  15
# Fraudulent Transactions Missed (False Negatives):  20
# Fraudulent Transactions Detected (True Positives):  7053
# Total Fraudulent Transactions:  7073
#
#
# F1-Score
# 0.9975249275157343
#
#
# Accuracy Score
# 0.9974016332590943
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6397
#            1       1.00      1.00      1.00      7073
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %% [markdown]
# ### We will build Deep Neural Model with L2 Regularization and Dropouts - Hyperparameter Tuning

# %% [markdown]
# #### Compile the Deep Neural Model

# %%
'''
This will build a deep neural network model with multiple hidden layers and implement 
L2 regularization
Dropout regularization
'''

deepmodel = make_DNNModel()
deepmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 128)               124642688
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 124,643,801
# Trainable params: 124,643,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the Deep Neural Model

# %%
# we will now train the model on training and validation data
# Now use the function to plot the confusion matrix

start = datetime.now()
epochs_history_deep = deepmodel.fit(features_train, target_train, epochs=EPOCHS,
                          validation_data=(features_val, target_val),
                          verbose=1)
end = datetime.now()
print(f"The training of simple model completed in time - {end - start}")
# Out:
# Epoch 1/10
# 688/688 [==============================] - 36s 51ms/step - loss: 0.0725 - tp: 10684.9739 - fp: 46.7025 - tn: 9708.2192 - fn: 29.0087 - accuracy: 0.9961 - precision: 0.9953 - recall: 0.9972 - auc: 0.9999 - val_loss: 0.0261 - val_tp: 4908.0000 - val_fp: 0.0000e+00 - val_tn: 4483.0000 - val_fn: 38.0000 - val_accuracy: 0.9960 - val_precision: 1.0000 - val_recall: 0.9923 - val_auc: 0.9994
# Epoch 2/10
# 688/688 [==============================] - 34s 50ms/step - loss: 0.0156 - tp: 5721.1829 - fp: 1.3266 - tn: 5305.1916 - fn: 12.2032 - accuracy: 0.9987 - precision: 0.9998 - recall: 0.9978 - auc: 1.0000 - val_loss: 0.0139 - val_tp: 4939.0000 - val_fp: 11.0000 - val_tn: 4472.0000 - val_fn: 7.0000 - val_accuracy: 0.9981 - val_precision: 0.9978 - val_recall: 0.9986 - val_auc: 0.9998
# Epoch 3/10
# 688/688 [==============================] - 35s 50ms/step - loss: 0.0113 - tp: 5753.8694 - fp: 0.9390 - tn: 5276.4180 - fn: 8.6778 - accuracy: 0.9991 - precision: 0.9998 - recall: 0.9985 - auc: 1.0000 - val_loss: 0.0104 - val_tp: 4941.0000 - val_fp: 8.0000 - val_tn: 4475.0000 - val_fn: 5.0000 - val_accuracy: 0.9986 - val_precision: 0.9984 - val_recall: 0.9990 - val_auc: 1.0000
# Epoch 4/10
# 688/688 [==============================] - 34s 50ms/step - loss: 0.0082 - tp: 5760.0842 - fp: 0.5239 - tn: 5268.4659 - fn: 10.8302 - accuracy: 0.9989 - precision: 0.9999 - recall: 0.9980 - auc: 1.0000 - val_loss: 0.0081 - val_tp: 4938.0000 - val_fp: 6.0000 - val_tn: 4477.0000 - val_fn: 8.0000 - val_accuracy: 0.9985 - val_precision: 0.9988 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 5/10
# 688/688 [==============================] - 35s 50ms/step - loss: 0.0066 - tp: 5759.3832 - fp: 1.9637 - tn: 5269.5733 - fn: 8.9840 - accuracy: 0.9992 - precision: 0.9998 - recall: 0.9987 - auc: 1.0000 - val_loss: 0.0077 - val_tp: 4939.0000 - val_fp: 3.0000 - val_tn: 4480.0000 - val_fn: 7.0000 - val_accuracy: 0.9989 - val_precision: 0.9994 - val_recall: 0.9986 - val_auc: 1.0000
# Epoch 6/10
# 688/688 [==============================] - 35s 50ms/step - loss: 0.0059 - tp: 5757.9753 - fp: 5.8650 - tn: 5273.3164 - fn: 2.7475 - accuracy: 0.9992 - precision: 0.9992 - recall: 0.9993 - auc: 1.0000 - val_loss: 0.0064 - val_tp: 4940.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 6.0000 - val_accuracy: 0.9988 - val_precision: 0.9990 - val_recall: 0.9988 - val_auc: 1.0000
# Epoch 7/10
# 688/688 [==============================] - 35s 50ms/step - loss: 0.0048 - tp: 5740.4659 - fp: 7.5922 - tn: 5287.7896 - fn: 4.0566 - accuracy: 0.9991 - precision: 0.9988 - recall: 0.9995 - auc: 1.0000 - val_loss: 0.0063 - val_tp: 4938.0000 - val_fp: 5.0000 - val_tn: 4478.0000 - val_fn: 8.0000 - val_accuracy: 0.9986 - val_precision: 0.9990 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 8/10
# 688/688 [==============================] - 34s 50ms/step - loss: 0.0045 - tp: 5787.4253 - fp: 9.1829 - tn: 5242.5791 - fn: 0.7170 - accuracy: 0.9992 - precision: 0.9986 - recall: 0.9999 - auc: 1.0000 - val_loss: 0.0063 - val_tp: 4938.0000 - val_fp: 3.0000 - val_tn: 4480.0000 - val_fn: 8.0000 - val_accuracy: 0.9988 - val_precision: 0.9994 - val_recall: 0.9984 - val_auc: 1.0000
# Epoch 9/10
# 688/688 [==============================] - 35s 51ms/step - loss: 0.0042 - tp: 5778.3149 - fp: 3.6386 - tn: 5251.4717 - fn: 6.4790 - accuracy: 0.9990 - precision: 0.9991 - recall: 0.9991 - auc: 1.0000 - val_loss: 0.0066 - val_tp: 4935.0000 - val_fp: 2.0000 - val_tn: 4481.0000 - val_fn: 11.0000 - val_accuracy: 0.9986 - val_precision: 0.9996 - val_recall: 0.9978 - val_auc: 1.0000
# Epoch 10/10
# 688/688 [==============================] - 34s 50ms/step - loss: 0.0039 - tp: 5756.3338 - fp: 7.3687 - tn: 5275.2221 - fn: 0.9797 - accuracy: 0.9994 - precision: 0.9989 - recall: 0.9999 - auc: 1.0000 - val_loss: 0.0059 - val_tp: 4934.0000 - val_fp: 2.0000 - val_tn: 4481.0000 - val_fn: 12.0000 - val_accuracy: 0.9985 - val_precision: 0.9996 - val_recall: 0.9976 - val_auc: 1.0000
# The training of simple model completed in time - 0:05:46.724890

# %% [markdown]
# #### Deep Neural Model Performance Graphs

# %%
# Plot Training Loss vs Validation Loss for the Deep Neural Model
plotTrainLossVsValLoss(epochs_history=epochs_history_deep)

# %%
# Plot the Training Accuracy vs Validation Accuracy for the Deep Neural Model
plotTrainAccuracyVsValAccuracy(epochs_history=epochs_history_deep)

# %% [markdown]
# #### Model Validations for the Deep Neural Model

# %%
# Let us run the predictions

target_predictions = deepmodel.predict(features_test)

# %%
# Now use the function to plot the confusion matrix
plot_cm (target_test, target_predictions)
# Out:
# Legitimate Transactions Detected (True Negatives):  6385
# Legitimate Transactions Incorrectly Detected (False Positives):  12
# Fraudulent Transactions Missed (False Negatives):  28
# Fraudulent Transactions Detected (True Positives):  7045
# Total Fraudulent Transactions:  7073
#
#
# F1-Score
# 0.9971691436659589
#
#
# Accuracy Score
# 0.9970304380103935
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6397
#            1       1.00      1.00      1.00      7073
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470
